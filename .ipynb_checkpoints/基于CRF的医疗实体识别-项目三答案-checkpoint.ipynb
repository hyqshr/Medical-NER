# %%
#导入数据分析所需的基础包
import pandas as pd
import numpy as np
import os

#包tqdm是用来对可迭代对象执行时生成一个进度条用以监视程序运行过程
from tqdm import tqdm

#导入训练集测试集划分的包
from sklearn.model_selection import train_test_split

#导入CRF模型所需的包
from sklearn_crfsuite import CRF

#导入模型评估所需的包
from sklearn_crfsuite import metrics

# %% [markdown]
# # 读取数据

# %% [markdown]
# 数据保存在data/目录下，data/目录下共有四个文件夹，分别对应四种医学情景：出院情况、病史特点、诊疗过程和一般项目。每个文件夹下保存了该情景下的电子病历。包括两类文件：'xxx-yyy.txtoriginal.txt'和'xxx-yyy.txt'。'xxx-yyy.txtoriginal.txt'保存了xxx情境下第yyy号病历的病历文本，保存在txt的第一行中。'xxx-yyy.txt'为其对应的标签数据。

# %% [markdown]
# 数据中共包含5种实体：治疗、身体部位、疾病和诊断、症状和体征、检查和检验。

# %%
# 读取一个病历文本数据，并查看其内容。
with open('data/一般项目/一般项目-1.txtoriginal.txt') as f:
    content = f.read().strip()
print(content)
# Out:
# 女性，88岁，农民，双滦区应营子村人，主因右髋部摔伤后疼痛肿胀，活动受限5小时于2016-10-29；11：12入院。

# %%
# 读取上述病历对应的标签数据
with open('data/一般项目/一般项目-1.txt') as f:
    content_label = f.read().strip()
print(content_label)
# Out:
# 右髋部	21	23	身体部位
# 疼痛	27	28	症状和体征
# 肿胀	29	30	症状和体征

# %% [markdown]
# 可以看出，标签文件的数据格式为每行对应一个实体，每行格式为“实体内容 实体在文本中的开始位置 实体在文本中的结束位置 实体类别”。如第一行表示content[21:24]对应的便是'右髋部'，为身体部位实体类别。

# %% [markdown]
# # 数据标注

# %% [markdown]
# 实体识别的数据标注方式主要有BIOES和BIO两种，详细的介绍参考实验手册。这里为使标注类别不至于太多，我们采用BIO方式。即将实体部分的第一个汉字标注为B，实体的其他部分的汉字标注为I，非实体部分标注为O。

# %% [markdown]
# 将5种实体类别治疗、身体部位、疾病和诊断、症状和体征、检查和检验分别标记为TREATMENT、BODY、DISEASES、SIGNS、EXAMINATIONS。

# %% [markdown]
# 则标记时，如：若为治疗类别的实体的第一个汉字，则将其标注为B-TREATMENT，该实体其他字标记为I-TREATMENT。

# %%
label_dict = {'治疗':'TREATMENT',
              '身体部位':'BODY',
              '疾病和诊断':'DISEASES',
              '症状和体征':'SIGNS',
              '检查和检验':'EXAMINATIONS'}

def sentence2BIOlabel(sentence,label_from_file):
    '''
        返回句子sentence的BIO标注列表
        入参：
            sentence：一个句子，字符串类别
            label_from_file：该句子对应的标签，格式为直接从txt文件中读出的格式，形如上文中的content_label
        出参：
            sentence_label：该句子的BIO标签。一个列表，列表的第i项为第i个汉字对应的标签
    '''
    #初始的sentence_label每个标签均定义为'O'。之后会修改其中实体部分的标签。
    sentence_label = ['O']*len(sentence)
    if label_from_file=='':
        return sentence_label
    #line为label_from_file中每一行的数据，对应一个实体的信息。格式为“实体内容 实体在文本中的开始位置 实体在文本中的结束位置 实体类别”
    for line in label_from_file.split('\n'):
        #entity_info中保存了单个实体的信息
        entity_info = line.strip().split('\t')
        start_index = int(entity_info[1])     #实体在文本中的开始位置
        end_index = int(entity_info[2])      #实体在文本中的结束位置
        entity_label = label_dict[entity_info[3]]      #实体标签类别
        #为实体的第一个汉字标记为B-xx
        sentence_label[start_index] = 'B-'+entity_label
        #为实体中的其他汉字标记为I-xx
        for i in range(start_index+1,end_index+1):
            sentence_label[i] = 'I-'+entity_label
    return sentence_label

# %%
#以上文中的content和content_label为例查看sentence2BIOlabel函数的使用方法
#返回上文中content对应的BIO标签并输出
sentence_label_tmp = sentence2BIOlabel(content,content_label)
print(sentence_label_tmp)
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-BODY', 'I-BODY', 'I-BODY', 'O', 'O', 'O', 'B-SIGNS', 'I-SIGNS', 'B-SIGNS', 'I-SIGNS', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
#输出content中每个汉字与BIO标签的对应关系
for i in range(len(content)):
    print(content[i],sentence_label_tmp[i])
# Out:
# 女 O
# 性 O
# ， O
# 8 O
# 8 O
# 岁 O
# ， O
# 农 O
# 民 O
# ， O
# 双 O
# 滦 O
# 区 O
# 应 O
# 营 O
# 子 O
# 村 O
# 人 O
# ， O
# 主 O
# 因 O
# 右 B-BODY
# 髋 I-BODY
# 部 I-BODY
# 摔 O
# 伤 O
# 后 O
# 疼 B-SIGNS
# 痛 I-SIGNS
# 肿 B-SIGNS
# 胀 I-SIGNS
# ， O
# 活 O
# 动 O
# 受 O
# 限 O
# 5 O
# 小 O
# 时 O
# 于 O
# 2 O
# 0 O
# 1 O
# 6 O
# - O
# 1 O
# 0 O
# - O
# 2 O
# 9 O
# ； O
# 1 O
# 1 O
# ： O
# 1 O
# 2 O
# 入 O
# 院 O
# 。 O

# %%
#将数据集中每个样本读进来并将其保存在sentence_list中，将每个样本对应的BIO标签保存在label_list中
#sentence_list的格式为[第一个句子，第二个句子，第三个句子，...，第n个句子]
#label_list的格式为[第一个句子对应的BIO标注列表，第二个句子对应的BIO标注列表，第三个句子对应的BIO标注列表，...，第n个句子对应的BIO标注列表]
sentence_list = []
label_list = []
for medical_situation in os.listdir('data/'):
    path = 'data/'+medical_situation+'/'
    if '.DS_Store' in path:
        continue
    for file_name in os.listdir(path):
        print (file_name)
        #判断文件名中是否包含'txtoriginal'。若包含'txtoriginal'说明为原始的病历文件，不包含说明为标签文件。
        #当为病历文件时，我们一次性处理该病历文件及其对应的标签文件。若为标签文件时忽略。
        if 'txtoriginal' in file_name:
            original_file = path+file_name    #病历文件所在的目录
            label_file = path+file_name.replace('.txtoriginal','')     #标签文件所在的目录
            #读取病历文件
            with open(original_file) as f:
                content = f.read().strip()
            #读取标签文件
            with open(label_file) as f:
                content_label = f.read().strip()
            #获取病历文本对应的BIO标注列表
            sentence_label = sentence2BIOlabel(content,content_label)
            #将病历文本加入sentence_list中
            sentence_list.append(content)
            #将其对应的BIO标签加入到label_list中
            label_list.append(sentence_label)
# Out:
# 诊疗过程-199.txt
# 诊疗过程-281.txtoriginal.txt
# 诊疗过程-161.txtoriginal.txt
# 诊疗过程-34.txtoriginal.txt
# 诊疗过程-227.txtoriginal.txt
# 诊疗过程-23.txt
# 诊疗过程-37.txt
# 诊疗过程-166.txt
# 诊疗过程-172.txt
# 诊疗过程-92.txtoriginal.txt
# 诊疗过程-73.txtoriginal.txt
# 诊疗过程-126.txtoriginal.txt
# 诊疗过程-238.txt
# 诊疗过程-210.txt
# 诊疗过程-180.txtoriginal.txt
# 诊疗过程-204.txt
# 诊疗过程-260.txtoriginal.txt
# 诊疗过程-205.txt
# 诊疗过程-244.txtoriginal.txt
# 诊疗过程-211.txt
# 诊疗过程-239.txt
# 诊疗过程-199.txtoriginal.txt
# 诊疗过程-279.txtoriginal.txt
# 诊疗过程-102.txtoriginal.txt
# 诊疗过程-57.txtoriginal.txt
# 诊疗过程-5.txtoriginal.txt
# 诊疗过程-173.txt
# 诊疗过程-167.txt
# 诊疗过程-298.txtoriginal.txt
# 诊疗过程-36.txt
# 诊疗过程-178.txtoriginal.txt
# 诊疗过程-203.txtoriginal.txt
# 诊疗过程-22.txt
# 诊疗过程-10.txtoriginal.txt
# 诊疗过程-145.txtoriginal.txt
# 诊疗过程-198.txt
# 诊疗过程-276.txtoriginal.txt
# 诊疗过程-8.txt
# 诊疗过程-196.txtoriginal.txt
# 诊疗过程-58.txtoriginal.txt
# 诊疗过程-130.txtoriginal.txt
# 诊疗过程-34.txt
# 诊疗过程-20.txt
# 诊疗过程-159.txt
# 诊疗过程-171.txt
# 诊疗过程-165.txt
# 诊疗过程-65.txtoriginal.txt
# 诊疗过程-84.txtoriginal.txt
# 诊疗过程-231.txtoriginal.txt
# 诊疗过程-22.txtoriginal.txt
# 诊疗过程-207.txt
# 诊疗过程-213.txt
# 诊疗过程-177.txtoriginal.txt
# 诊疗过程-297.txtoriginal.txt
# 诊疗过程-153.txtoriginal.txt
# 诊疗过程-212.txt
# 诊疗过程-228.txtoriginal.txt
# 诊疗过程-206.txt
# 诊疗过程-215.txtoriginal.txt
# 诊疗过程-41.txtoriginal.txt
# 诊疗过程-164.txt
# 诊疗过程-170.txt
# 诊疗过程-21.txt
# 诊疗过程-158.txt
# 诊疗过程-114.txtoriginal.txt
# 诊疗过程-35.txt
# 诊疗过程-252.txtoriginal.txt
# 诊疗过程-9.txt
# 诊疗过程-129.txtoriginal.txt
# 诊疗过程-255.txtoriginal.txt
# 诊疗过程-174.txt
# 诊疗过程-113.txtoriginal.txt
# 诊疗过程-160.txt
# 诊疗过程-188.txtoriginal.txt
# 诊疗过程-268.txtoriginal.txt
# 诊疗过程-19.txt
# 诊疗过程-31.txt
# 诊疗过程-148.txt
# 诊疗过程-46.txtoriginal.txt
# 诊疗过程-25.txt
# 诊疗过程-212.txtoriginal.txt
# 诊疗过程-289.txtoriginal.txt
# 诊疗过程-169.txtoriginal.txt
# 诊疗过程-202.txt
# 诊疗过程-216.txt
# 诊疗过程-154.txtoriginal.txt
# 诊疗过程-290.txtoriginal.txt
# 诊疗过程-170.txtoriginal.txt
# 诊疗过程-217.txt
# 诊疗过程-203.txt
# 诊疗过程-25.txtoriginal.txt
# 诊疗过程-236.txtoriginal.txt
# 诊疗过程-83.txtoriginal.txt
# 诊疗过程-18.txtoriginal.txt
# 诊疗过程-62.txtoriginal.txt
# 诊疗过程-24.txt
# 诊疗过程-30.txt
# 诊疗过程-149.txt
# 诊疗过程-161.txt
# 诊疗过程-18.txt
# 诊疗过程-137.txtoriginal.txt
# 诊疗过程-175.txt
# 诊疗过程-271.txtoriginal.txt
# 诊疗过程-239.txtoriginal.txt
# 诊疗过程-142.txtoriginal.txt
# 诊疗过程-17.txtoriginal.txt
# 诊疗过程-188.txt
# 诊疗过程-204.txtoriginal.txt
# 诊疗过程-163.txt
# 诊疗过程-177.txt
# 诊疗过程-26.txt
# 诊疗过程-32.txt
# 诊疗过程-2.txtoriginal.txt
# 诊疗过程-50.txtoriginal.txt
# 诊疗过程-105.txtoriginal.txt
# 诊疗过程-215.txt
# 诊疗过程-201.txt
# 诊疗过程-138.txtoriginal.txt
# 诊疗过程-229.txt
# 诊疗过程-243.txtoriginal.txt
# 诊疗过程-267.txtoriginal.txt
# 诊疗过程-187.txtoriginal.txt
# 诊疗过程-228.txt
# 诊疗过程-49.txtoriginal.txt
# 诊疗过程-200.txt
# 诊疗过程-214.txt
# 诊疗过程-121.txtoriginal.txt
# 诊疗过程-74.txtoriginal.txt
# 诊疗过程-95.txtoriginal.txt
# 诊疗过程-33.txt
# 诊疗过程-27.txt
# 诊疗过程-176.txt
# 诊疗过程-220.txtoriginal.txt
# 诊疗过程-162.txt
# 诊疗过程-189.txt
# 诊疗过程-33.txtoriginal.txt
# 诊疗过程-166.txtoriginal.txt
# 诊疗过程-286.txtoriginal.txt
# 诊疗过程-83.txt
# 诊疗过程-213.txtoriginal.txt
# 诊疗过程-288.txtoriginal.txt
# 诊疗过程-168.txtoriginal.txt
# 诊疗过程-97.txt
# 诊疗过程-40.txt
# 诊疗过程-139.txt
# 诊疗过程-155.txtoriginal.txt
# 诊疗过程-54.txt
# 诊疗过程-105.txt
# 诊疗过程-111.txt
# 诊疗过程-68.txt
# 诊疗过程-298.txt
# 诊疗过程-254.txtoriginal.txt
# 诊疗过程-47.txtoriginal.txt
# 诊疗过程-273.txt
# 诊疗过程-112.txtoriginal.txt
# 诊疗过程-189.txtoriginal.txt
# 诊疗过程-267.txt
# 诊疗过程-269.txtoriginal.txt
# 诊疗过程-266.txt
# 诊疗过程-272.txt
# 诊疗过程-136.txtoriginal.txt
# 诊疗过程-63.txtoriginal.txt
# 诊疗过程-190.txtoriginal.txt
# 诊疗过程-270.txtoriginal.txt
# 诊疗过程-299.txt
# 诊疗过程-110.txt
# 诊疗过程-69.txt
# 诊疗过程-24.txtoriginal.txt
# 诊疗过程-104.txt
# 诊疗过程-291.txtoriginal.txt
# 诊疗过程-55.txt
# 诊疗过程-171.txtoriginal.txt
# 诊疗过程-41.txt
# 诊疗过程-138.txt
# 诊疗过程-82.txtoriginal.txt
# 诊疗过程-19.txtoriginal.txt
# 诊疗过程-96.txt
# 诊疗过程-82.txt
# 诊疗过程-237.txtoriginal.txt
# 诊疗过程-94.txt
# 诊疗过程-104.txtoriginal.txt
# 诊疗过程-80.txt
# 诊疗过程-51.txtoriginal.txt
# 诊疗过程-139.txtoriginal.txt
# 诊疗过程-57.txt
# 诊疗过程-242.txtoriginal.txt
# 诊疗过程-43.txt
# 诊疗过程-112.txt
# 诊疗过程-106.txt
# 诊疗过程-16.txtoriginal.txt
# 诊疗过程-238.txtoriginal.txt
# 诊疗过程-143.txtoriginal.txt
# 诊疗过程-258.txt
# 诊疗过程-205.txtoriginal.txt
# 诊疗过程-264.txt
# 诊疗过程-270.txt
# 诊疗过程-3.txtoriginal.txt
# 诊疗过程-271.txt
# 诊疗过程-221.txtoriginal.txt
# 诊疗过程-265.txt
# 诊疗过程-94.txtoriginal.txt
# 诊疗过程-259.txt
# 诊疗过程-167.txtoriginal.txt
# 诊疗过程-287.txtoriginal.txt
# 诊疗过程-32.txtoriginal.txt
# 诊疗过程-107.txt
# 诊疗过程-48.txtoriginal.txt
# 诊疗过程-113.txt
# 诊疗过程-266.txtoriginal.txt
# 诊疗过程-186.txtoriginal.txt
# 诊疗过程-42.txt
# 诊疗过程-56.txt
# 诊疗过程-75.txtoriginal.txt
# 诊疗过程-81.txt
# 诊疗过程-120.txtoriginal.txt
# 诊疗过程-95.txt
# 诊疗过程-127.txtoriginal.txt
# 诊疗过程-91.txt
# 诊疗过程-72.txtoriginal.txt
# 诊疗过程-85.txt
# 诊疗过程-117.txt
# 诊疗过程-181.txtoriginal.txt
# 诊疗过程-103.txt
# 诊疗过程-261.txtoriginal.txt
# 诊疗过程-52.txt
# 诊疗过程-46.txt
# 诊疗过程-35.txtoriginal.txt
# 诊疗过程-280.txtoriginal.txt
# 诊疗过程-160.txtoriginal.txt
# 诊疗过程-261.txt
# 诊疗过程-275.txt
# 诊疗过程-93.txtoriginal.txt
# 诊疗过程-226.txtoriginal.txt
# 诊疗过程-249.txt
# 诊疗过程-4.txtoriginal.txt
# 诊疗过程-299.txtoriginal.txt
# 诊疗过程-248.txt
# 诊疗过程-179.txtoriginal.txt
# 诊疗过程-202.txtoriginal.txt
# 诊疗过程-274.txt
# 诊疗过程-260.txt
# 诊疗过程-144.txtoriginal.txt
# 诊疗过程-11.txtoriginal.txt
# 诊疗过程-300.txt
# 诊疗过程-47.txt
# 诊疗过程-53.txt
# 诊疗过程-245.txtoriginal.txt
# 诊疗过程-102.txt
# 诊疗过程-116.txt
# 诊疗过程-84.txt
# 诊疗过程-56.txtoriginal.txt
# 诊疗过程-90.txt
# 诊疗过程-198.txtoriginal.txt
# 诊疗过程-278.txtoriginal.txt
# 诊疗过程-103.txtoriginal.txt
# 诊疗过程-230.txtoriginal.txt
# 诊疗过程-86.txt
# 诊疗过程-85.txtoriginal.txt
# 诊疗过程-92.txt
# 诊疗过程-100.txt
# 诊疗过程-79.txt
# 诊疗过程-176.txtoriginal.txt
# 诊疗过程-114.txt
# 诊疗过程-296.txtoriginal.txt
# 诊疗过程-45.txt
# 诊疗过程-23.txtoriginal.txt
# 诊疗过程-51.txt
# 诊疗过程-128.txt
# 诊疗过程-59.txtoriginal.txt
# 诊疗过程-289.txt
# 诊疗过程-277.txtoriginal.txt
# 诊疗过程-197.txtoriginal.txt
# 诊疗过程-276.txt
# 诊疗过程-262.txt
# 诊疗过程-64.txtoriginal.txt
# 诊疗过程-131.txtoriginal.txt
# 诊疗过程-115.txtoriginal.txt
# 诊疗过程-263.txt
# 诊疗过程-40.txtoriginal.txt
# 诊疗过程-277.txt
# 诊疗过程-253.txtoriginal.txt
# 诊疗过程-128.txtoriginal.txt
# 诊疗过程-288.txt
# 诊疗过程-50.txt
# 诊疗过程-129.txt
# 诊疗过程-44.txt
# 诊疗过程-152.txtoriginal.txt
# 诊疗过程-115.txt
# 诊疗过程-229.txtoriginal.txt
# 诊疗过程-101.txt
# 诊疗过程-78.txt
# 诊疗过程-93.txt
# 诊疗过程-87.txt
# 诊疗过程-214.txtoriginal.txt
# 诊疗过程-61.txt
# 诊疗过程-118.txt
# 诊疗过程-75.txt
# 诊疗过程-124.txt
# 诊疗过程-130.txt
# 诊疗过程-49.txt
# 诊疗过程-272.txtoriginal.txt
# 诊疗过程-192.txtoriginal.txt
# 诊疗过程-109.txtoriginal.txt
# 诊疗过程-134.txtoriginal.txt
# 诊疗过程-300.txtoriginal.txt
# 诊疗过程-61.txtoriginal.txt
# 诊疗过程-291.txt
# 诊疗过程-285.txt
# 诊疗过程-252.txt
# 诊疗过程-246.txt
# 诊疗过程-80.txtoriginal.txt
# 诊疗过程-235.txtoriginal.txt
# 诊疗过程-26.txtoriginal.txt
# 诊疗过程-173.txtoriginal.txt
# 诊疗过程-293.txtoriginal.txt
# 诊疗过程-208.txtoriginal.txt
# 诊疗过程-157.txtoriginal.txt
# 诊疗过程-99.txtoriginal.txt
# 诊疗过程-211.txtoriginal.txt
# 诊疗过程-247.txt
# 诊疗过程-253.txt
# 诊疗过程-284.txt
# 诊疗过程-290.txt
# 诊疗过程-45.txtoriginal.txt
# 诊疗过程-110.txtoriginal.txt
# 诊疗过程-78.txtoriginal.txt
# 诊疗过程-256.txtoriginal.txt
# 诊疗过程-131.txt
# 诊疗过程-48.txt
# 诊疗过程-125.txt
# 诊疗过程-74.txt
# 诊疗过程-60.txt
# 诊疗过程-119.txt
# 诊疗过程-89.txt
# 诊疗过程-76.txt
# 诊疗过程-62.txt
# 诊疗过程-133.txt
# 诊疗过程-127.txt
# 诊疗过程-285.txtoriginal.txt
# 诊疗过程-165.txtoriginal.txt
# 诊疗过程-30.txtoriginal.txt
# 诊疗过程-158.txtoriginal.txt
# 诊疗过程-223.txtoriginal.txt
# 诊疗过程-96.txtoriginal.txt
# 诊疗过程-286.txt
# 诊疗过程-292.txt
# 诊疗过程-279.txt
# 诊疗过程-245.txt
# 诊疗过程-251.txt
# 诊疗过程-77.txtoriginal.txt
# 诊疗过程-259.txtoriginal.txt
# 诊疗过程-122.txtoriginal.txt
# 诊疗过程-184.txtoriginal.txt
# 诊疗过程-264.txtoriginal.txt
# 诊疗过程-240.txtoriginal.txt
# 诊疗过程-106.txtoriginal.txt
# 诊疗过程-53.txtoriginal.txt
# 诊疗过程-250.txt
# 诊疗过程-244.txt
# 诊疗过程-278.txt
# 诊疗过程-293.txt
# 诊疗过程-287.txt
# 诊疗过程-29.txtoriginal.txt
# 诊疗过程-207.txtoriginal.txt
# 诊疗过程-14.txtoriginal.txt
# 诊疗过程-141.txtoriginal.txt
# 诊疗过程-126.txt
# 诊疗过程-132.txt
# 诊疗过程-63.txt
# 诊疗过程-77.txt
# 诊疗过程-88.txt
# 诊疗过程-1.txtoriginal.txt
# 诊疗过程-6.txtoriginal.txt
# 诊疗过程-98.txt
# 诊疗过程-136.txt
# 诊疗过程-122.txt
# 诊疗过程-73.txt
# 诊疗过程-67.txt
# 诊疗过程-146.txtoriginal.txt
# 诊疗过程-88.txtoriginal.txt
# 诊疗过程-13.txtoriginal.txt
# 诊疗过程-200.txtoriginal.txt
# 诊疗过程-283.txt
# 诊疗过程-297.txt
# 诊疗过程-240.txt
# 诊疗过程-254.txt
# 诊疗过程-268.txt
# 诊疗过程-54.txtoriginal.txt
# 诊疗过程-101.txtoriginal.txt
# 诊疗过程-69.txtoriginal.txt
# 诊疗过程-247.txtoriginal.txt
# 诊疗过程-118.txtoriginal.txt
# 诊疗过程-263.txtoriginal.txt
# 诊疗过程-183.txtoriginal.txt
# 诊疗过程-125.txtoriginal.txt
# 诊疗过程-70.txtoriginal.txt
# 诊疗过程-269.txt
# 诊疗过程-255.txt
# 诊疗过程-241.txt
# 诊疗过程-296.txt
# 诊疗过程-282.txt
# 诊疗过程-91.txtoriginal.txt
# 诊疗过程-224.txtoriginal.txt
# 诊疗过程-37.txtoriginal.txt
# 诊疗过程-219.txtoriginal.txt
# 诊疗过程-162.txtoriginal.txt
# 诊疗过程-282.txtoriginal.txt
# 诊疗过程-66.txt
# 诊疗过程-72.txt
# 诊疗过程-123.txt
# 诊疗过程-137.txt
# 诊疗过程-99.txt
# 诊疗过程-121.txt
# 诊疗过程-58.txt
# 诊疗过程-135.txt
# 诊疗过程-64.txt
# 诊疗过程-70.txt
# 诊疗过程-109.txt
# 诊疗过程-251.txtoriginal.txt
# 诊疗过程-117.txtoriginal.txt
# 诊疗过程-42.txtoriginal.txt
# 诊疗过程-294.txt
# 诊疗过程-280.txt
# 诊疗过程-257.txt
# 诊疗过程-243.txt
# 诊疗过程-38.txtoriginal.txt
# 诊疗过程-216.txtoriginal.txt
# 诊疗过程-150.txtoriginal.txt
# 诊疗过程-294.txtoriginal.txt
# 诊疗过程-174.txtoriginal.txt
# 诊疗过程-21.txtoriginal.txt
# 诊疗过程-232.txtoriginal.txt
# 诊疗过程-149.txtoriginal.txt
# 诊疗过程-87.txtoriginal.txt
# 诊疗过程-242.txt
# 诊疗过程-256.txt
# 诊疗过程-9.txtoriginal.txt
# 诊疗过程-281.txt
# 诊疗过程-295.txt
# 诊疗过程-66.txtoriginal.txt
# 诊疗过程-133.txtoriginal.txt
# 诊疗过程-248.txtoriginal.txt
# 诊疗过程-195.txtoriginal.txt
# 诊疗过程-275.txtoriginal.txt
# 诊疗过程-71.txt
# 诊疗过程-108.txt
# 诊疗过程-65.txt
# 诊疗过程-134.txt
# 诊疗过程-120.txt
# 诊疗过程-59.txt
# 诊疗过程-184.txt
# 诊疗过程-2.txt
# 诊疗过程-190.txt
# 诊疗过程-16.txt
# 诊疗过程-147.txt
# 诊疗过程-153.txt
# 诊疗过程-100.txtoriginal.txt
# 诊疗过程-55.txtoriginal.txt
# 诊疗过程-246.txtoriginal.txt
# 诊疗过程-68.txtoriginal.txt
# 诊疗过程-7.txtoriginal.txt
# 诊疗过程-219.txt
# 诊疗过程-231.txt
# 诊疗过程-225.txt
# 诊疗过程-89.txtoriginal.txt
# 诊疗过程-12.txtoriginal.txt
# 诊疗过程-147.txtoriginal.txt
# 诊疗过程-201.txtoriginal.txt
# 诊疗过程-225.txtoriginal.txt
# 诊疗过程-90.txtoriginal.txt
# 诊疗过程-218.txtoriginal.txt
# 诊疗过程-163.txtoriginal.txt
# 诊疗过程-283.txtoriginal.txt
# 诊疗过程-36.txtoriginal.txt
# 诊疗过程-224.txt
# 诊疗过程-230.txt
# 诊疗过程-218.txt
# 诊疗过程-119.txtoriginal.txt
# 诊疗过程-262.txtoriginal.txt
# 诊疗过程-182.txtoriginal.txt
# 诊疗过程-71.txtoriginal.txt
# 诊疗过程-124.txtoriginal.txt
# 诊疗过程-152.txt
# 诊疗过程-146.txt
# 诊疗过程-17.txt
# 诊疗过程-3.txt
# 诊疗过程-185.txt
# 诊疗过程-1.txt
# 诊疗过程-193.txt
# 诊疗过程-187.txt
# 诊疗过程-15.txt
# 诊疗过程-178.txt
# 诊疗过程-150.txt
# 诊疗过程-29.txt
# 诊疗过程-144.txt
# 诊疗过程-217.txtoriginal.txt
# 诊疗过程-39.txtoriginal.txt
# 诊疗过程-151.txtoriginal.txt
# 诊疗过程-226.txt
# 诊疗过程-232.txt
# 诊疗过程-250.txtoriginal.txt
# 诊疗过程-43.txtoriginal.txt
# 诊疗过程-116.txtoriginal.txt
# 诊疗过程-132.txtoriginal.txt
# 诊疗过程-249.txtoriginal.txt
# 诊疗过程-67.txtoriginal.txt
# 诊疗过程-194.txtoriginal.txt
# 诊疗过程-274.txtoriginal.txt
# 诊疗过程-233.txt
# 诊疗过程-227.txt
# 诊疗过程-20.txtoriginal.txt
# 诊疗过程-295.txtoriginal.txt
# 诊疗过程-175.txtoriginal.txt
# 诊疗过程-86.txtoriginal.txt
# 诊疗过程-233.txtoriginal.txt
# 诊疗过程-148.txtoriginal.txt
# 诊疗过程-145.txt
# 诊疗过程-151.txt
# 诊疗过程-28.txt
# 诊疗过程-179.txt
# 诊疗过程-14.txt
# 诊疗过程-186.txt
# 诊疗过程-192.txt
# 诊疗过程-8.txtoriginal.txt
# 诊疗过程-4.txt
# 诊疗过程-196.txt
# 诊疗过程-182.txt
# 诊疗过程-155.txt
# 诊疗过程-141.txt
# 诊疗过程-38.txt
# 诊疗过程-10.txt
# 诊疗过程-169.txt
# 诊疗过程-234.txtoriginal.txt
# 诊疗过程-81.txtoriginal.txt
# 诊疗过程-172.txtoriginal.txt
# 诊疗过程-292.txtoriginal.txt
# 诊疗过程-209.txtoriginal.txt
# 诊疗过程-27.txtoriginal.txt
# 诊疗过程-223.txt
# 诊疗过程-237.txt
# 诊疗过程-273.txtoriginal.txt
# 诊疗过程-193.txtoriginal.txt
# 诊疗过程-108.txtoriginal.txt
# 诊疗过程-60.txtoriginal.txt
# 诊疗过程-135.txtoriginal.txt
# 诊疗过程-111.txtoriginal.txt
# 诊疗过程-44.txtoriginal.txt
# 诊疗过程-257.txtoriginal.txt
# 诊疗过程-79.txtoriginal.txt
# 诊疗过程-236.txt
# 诊疗过程-222.txt
# 诊疗过程-98.txtoriginal.txt
# 诊疗过程-156.txtoriginal.txt
# 诊疗过程-210.txtoriginal.txt
# 诊疗过程-11.txt
# 诊疗过程-168.txt
# 诊疗过程-140.txt
# 诊疗过程-39.txt
# 诊疗过程-154.txt
# 诊疗过程-183.txt
# 诊疗过程-197.txt
# 诊疗过程-5.txt
# 诊疗过程-181.txt
# 诊疗过程-7.txt
# 诊疗过程-195.txt
# 诊疗过程-142.txt
# 诊疗过程-156.txt
# 诊疗过程-13.txt
# 诊疗过程-258.txtoriginal.txt
# 诊疗过程-123.txtoriginal.txt
# 诊疗过程-76.txtoriginal.txt
# 诊疗过程-185.txtoriginal.txt
# 诊疗过程-265.txtoriginal.txt
# 诊疗过程-234.txt
# 诊疗过程-220.txt
# 诊疗过程-208.txt
# 诊疗过程-31.txtoriginal.txt
# 诊疗过程-284.txtoriginal.txt
# 诊疗过程-164.txtoriginal.txt
# 诊疗过程-97.txtoriginal.txt
# 诊疗过程-159.txtoriginal.txt
# 诊疗过程-222.txtoriginal.txt
# 诊疗过程-206.txtoriginal.txt
# 诊疗过程-28.txtoriginal.txt
# 诊疗过程-140.txtoriginal.txt
# 诊疗过程-15.txtoriginal.txt
# 诊疗过程-209.txt
# 诊疗过程-221.txt
# 诊疗过程-235.txt
# 诊疗过程-241.txtoriginal.txt
# 诊疗过程-52.txtoriginal.txt
# 诊疗过程-107.txtoriginal.txt
# 诊疗过程-12.txt
# 诊疗过程-157.txt
# 诊疗过程-143.txt
# 诊疗过程-194.txt
# 诊疗过程-6.txt
# 诊疗过程-180.txt
# 病史特点-135.txtoriginal.txt
# 病史特点-108.txtoriginal.txt
# 病史特点-273.txtoriginal.txt
# 病史特点-193.txtoriginal.txt
# 病史特点-280.txt
# 病史特点-294.txt
# 病史特点-80.txtoriginal.txt
# 病史特点-243.txt
# 病史特点-257.txt
# 病史特点-26.txtoriginal.txt
# 病史特点-209.txtoriginal.txt
# 病史特点-172.txtoriginal.txt
# 病史特点-292.txtoriginal.txt
# 病史特点-234.txtoriginal.txt
# 病史特点-88.txt
# 病史特点-135.txt
# 病史特点-121.txt
# 病史特点-61.txtoriginal.txt
# 病史特点-63.txt
# 病史特点-109.txt
# 病史特点-77.txt
# 病史特点-76.txt
# 病史特点-62.txt
# 病史特点-108.txt
# 病史特点-120.txt
# 病史特点-45.txtoriginal.txt
# 病史特点-134.txt
# 病史特点-89.txt
# 病史特点-78.txtoriginal.txt
# 病史特点-210.txtoriginal.txt
# 病史特点-156.txtoriginal.txt
# 病史特点-99.txtoriginal.txt
# 病史特点-256.txt
# 病史特点-242.txt
# 病史特点-295.txt
# 病史特点-281.txt
# 病史特点-257.txtoriginal.txt
# 病史特点-111.txtoriginal.txt
# 病史特点-222.txtoriginal.txt
# 病史特点-159.txtoriginal.txt
# 病史特点-284.txtoriginal.txt
# 病史特点-164.txtoriginal.txt
# 病史特点-297.txt
# 病史特点-283.txt
# 病史特点-77.txtoriginal.txt
# 病史特点-254.txt
# 病史特点-240.txt
# 病史特点-268.txt
# 病史特点-185.txtoriginal.txt
# 病史特点-265.txtoriginal.txt
# 病史特点-123.txtoriginal.txt
# 病史特点-258.txtoriginal.txt
# 病史特点-30.txtoriginal.txt
# 病史特点-48.txt
# 病史特点-122.txt
# 病史特点-136.txt
# 病史特点-96.txtoriginal.txt
# 病史特点-74.txt
# 病史特点-60.txt
# 病史特点-61.txt
# 病史特点-75.txt
# 病史特点-137.txt
# 病史特点-29.txtoriginal.txt
# 病史特点-49.txt
# 病史特点-123.txt
# 病史特点-14.txtoriginal.txt
# 病史特点-107.txtoriginal.txt
# 病史特点-241.txtoriginal.txt
# 病史特点-269.txt
# 病史特点-241.txt
# 病史特点-255.txt
# 病史特点-53.txtoriginal.txt
# 病史特点-1.txtoriginal.txt
# 病史特点-282.txt
# 病史特点-296.txt
# 病史特点-140.txtoriginal.txt
# 病史特点-206.txtoriginal.txt
# 病史特点-201.txtoriginal.txt
# 病史特点-147.txtoriginal.txt
# 病史特点-6.txtoriginal.txt
# 病史特点-292.txt
# 病史特点-286.txt
# 病史特点-54.txtoriginal.txt
# 病史特点-279.txt
# 病史特点-251.txt
# 病史特点-245.txt
# 病史特点-69.txtoriginal.txt
# 病史特点-246.txtoriginal.txt
# 病史特点-100.txtoriginal.txt
# 病史特点-13.txtoriginal.txt
# 病史特点-88.txtoriginal.txt
# 病史特点-71.txt
# 病史特点-65.txt
# 病史特点-127.txt
# 病史特点-59.txt
# 病史特点-133.txt
# 病史特点-58.txt
# 病史特点-132.txt
# 病史特点-126.txt
# 病史特点-91.txtoriginal.txt
# 病史特点-64.txt
# 病史特点-70.txt
# 病史特点-37.txtoriginal.txt
# 病史特点-124.txtoriginal.txt
# 病史特点-262.txtoriginal.txt
# 病史特点-182.txtoriginal.txt
# 病史特点-119.txtoriginal.txt
# 病史特点-244.txt
# 病史特点-250.txt
# 病史特点-278.txt
# 病史特点-287.txt
# 病史特点-70.txtoriginal.txt
# 病史特点-293.txt
# 病史特点-163.txtoriginal.txt
# 病史特点-283.txtoriginal.txt
# 病史特点-218.txtoriginal.txt
# 病史特点-225.txtoriginal.txt
# 病史特点-116.txtoriginal.txt
# 病史特点-250.txtoriginal.txt
# 病史特点-38.txtoriginal.txt
# 病史特点-285.txt
# 病史特点-291.txt
# 病史特点-246.txt
# 病史特点-252.txt
# 病史特点-151.txtoriginal.txt
# 病史特点-217.txtoriginal.txt
# 病史特点-99.txt
# 病史特点-66.txt
# 病史特点-42.txtoriginal.txt
# 病史特点-72.txt
# 病史特点-118.txt
# 病史特点-130.txt
# 病史特点-124.txt
# 病史特点-125.txt
# 病史特点-131.txt
# 病史特点-73.txt
# 病史特点-66.txtoriginal.txt
# 病史特点-119.txt
# 病史特点-67.txt
# 病史特点-98.txt
# 病史特点-9.txtoriginal.txt
# 病史特点-148.txtoriginal.txt
# 病史特点-233.txtoriginal.txt
# 病史特点-295.txtoriginal.txt
# 病史特点-175.txtoriginal.txt
# 病史特点-253.txt
# 病史特点-21.txtoriginal.txt
# 病史特点-247.txt
# 病史特点-290.txt
# 病史特点-87.txtoriginal.txt
# 病史特点-284.txt
# 病史特点-194.txtoriginal.txt
# 病史特点-274.txtoriginal.txt
# 病史特点-249.txtoriginal.txt
# 病史特点-132.txtoriginal.txt
# 病史特点-247.txtoriginal.txt
# 病史特点-101.txtoriginal.txt
# 病史特点-12.txtoriginal.txt
# 病史特点-89.txtoriginal.txt
# 病史特点-220.txt
# 病史特点-234.txt
# 病史特点-208.txt
# 病史特点-200.txtoriginal.txt
# 病史特点-146.txtoriginal.txt
# 病史特点-195.txt
# 病史特点-7.txtoriginal.txt
# 病史特点-55.txtoriginal.txt
# 病史特点-181.txt
# 病史特点-156.txt
# 病史特点-28.txt
# 病史特点-142.txt
# 病史特点-68.txtoriginal.txt
# 病史特点-14.txt
# 病史特点-15.txt
# 病史特点-29.txt
# 病史特点-143.txt
# 病史特点-157.txt
# 病史特点-71.txtoriginal.txt
# 病史特点-180.txt
# 病史特点-194.txt
# 病史特点-162.txtoriginal.txt
# 病史特点-282.txtoriginal.txt
# 病史特点-219.txtoriginal.txt
# 病史特点-224.txtoriginal.txt
# 病史特点-90.txtoriginal.txt
# 病史特点-209.txt
# 病史特点-235.txt
# 病史特点-221.txt
# 病史特点-36.txtoriginal.txt
# 病史特点-125.txtoriginal.txt
# 病史特点-263.txtoriginal.txt
# 病史特点-183.txtoriginal.txt
# 病史特点-118.txtoriginal.txt
# 病史特点-150.txtoriginal.txt
# 病史特点-216.txtoriginal.txt
# 病史特点-8.txt
# 病史特点-237.txt
# 病史特点-223.txt
# 病史特点-43.txtoriginal.txt
# 病史特点-117.txtoriginal.txt
# 病史特点-251.txtoriginal.txt
# 病史特点-39.txtoriginal.txt
# 病史特点-182.txt
# 病史特点-196.txt
# 病史特点-141.txt
# 病史特点-155.txt
# 病史特点-17.txt
# 病史特点-169.txt
# 病史特点-168.txt
# 病史特点-16.txt
# 病史特点-154.txt
# 病史特点-20.txtoriginal.txt
# 病史特点-140.txt
# 病史特点-86.txtoriginal.txt
# 病史特点-197.txt
# 病史特点-183.txt
# 病史特点-195.txtoriginal.txt
# 病史特点-275.txtoriginal.txt
# 病史特点-248.txtoriginal.txt
# 病史特点-133.txtoriginal.txt
# 病史特点-67.txtoriginal.txt
# 病史特点-222.txt
# 病史特点-236.txt
# 病史特点-8.txtoriginal.txt
# 病史特点-9.txt
# 病史特点-149.txtoriginal.txt
# 病史特点-232.txtoriginal.txt
# 病史特点-294.txtoriginal.txt
# 病史特点-174.txtoriginal.txt
# 病史特点-208.txtoriginal.txt
# 病史特点-173.txtoriginal.txt
# 病史特点-293.txtoriginal.txt
# 病史特点-235.txtoriginal.txt
# 病史特点-232.txt
# 病史特点-226.txt
# 病史特点-60.txtoriginal.txt
# 病史特点-300.txtoriginal.txt
# 病史特点-134.txtoriginal.txt
# 病史特点-109.txtoriginal.txt
# 病史特点-272.txtoriginal.txt
# 病史特点-192.txtoriginal.txt
# 病史特点-81.txtoriginal.txt
# 病史特点-187.txt
# 病史特点-193.txt
# 病史特点-12.txt
# 病史特点-27.txtoriginal.txt
# 病史特点-178.txt
# 病史特点-144.txt
# 病史特点-150.txt
# 病史特点-151.txt
# 病史特点-145.txt
# 病史特点-98.txtoriginal.txt
# 病史特点-13.txt
# 病史特点-179.txt
# 病史特点-192.txt
# 病史特点-186.txt
# 病史特点-256.txtoriginal.txt
# 病史特点-110.txtoriginal.txt
# 病史特点-44.txtoriginal.txt
# 病史特点-227.txt
# 病史特点-233.txt
# 病史特点-79.txtoriginal.txt
# 病史特点-211.txtoriginal.txt
# 病史特点-157.txtoriginal.txt
# 病史特点-184.txtoriginal.txt
# 病史特点-264.txtoriginal.txt
# 病史特点-122.txtoriginal.txt
# 病史特点-259.txtoriginal.txt
# 病史特点-31.txtoriginal.txt
# 病史特点-219.txt
# 病史特点-225.txt
# 病史特点-97.txtoriginal.txt
# 病史特点-231.txt
# 病史特点-223.txtoriginal.txt
# 病史特点-158.txtoriginal.txt
# 病史特点-285.txtoriginal.txt
# 病史特点-165.txtoriginal.txt
# 病史特点-76.txtoriginal.txt
# 病史特点-190.txt
# 病史特点-184.txt
# 病史特点-11.txt
# 病史特点-39.txt
# 病史特点-153.txt
# 病史特点-147.txt
# 病史特点-146.txt
# 病史特点-38.txt
# 病史特点-152.txt
# 病史特点-10.txt
# 病史特点-185.txt
# 病史特点-191.txt
# 病史特点-52.txtoriginal.txt
# 病史特点-141.txtoriginal.txt
# 病史特点-207.txtoriginal.txt
# 病史特点-230.txt
# 病史特点-28.txtoriginal.txt
# 病史特点-224.txt
# 病史特点-218.txt
# 病史特点-15.txtoriginal.txt
# 病史特点-106.txtoriginal.txt
# 病史特点-240.txtoriginal.txt
# 病史特点-73.txtoriginal.txt
# 病史特点-2.txt
# 病史特点-226.txtoriginal.txt
# 病史特点-280.txtoriginal.txt
# 病史特点-160.txtoriginal.txt
# 病史特点-201.txt
# 病史特点-215.txt
# 病史特点-229.txt
# 病史特点-34.txtoriginal.txt
# 病史特点-92.txtoriginal.txt
# 病史特点-188.txt
# 病史特点-181.txtoriginal.txt
# 病史特点-261.txtoriginal.txt
# 病史特点-177.txt
# 病史特点-163.txt
# 病史特点-21.txt
# 病史特点-35.txt
# 病史特点-127.txtoriginal.txt
# 病史特点-34.txt
# 病史特点-103.txtoriginal.txt
# 病史特点-198.txtoriginal.txt
# 病史特点-278.txtoriginal.txt
# 病史特点-20.txt
# 病史特点-162.txt
# 病史特点-176.txt
# 病史特点-189.txt
# 病史特点-245.txtoriginal.txt
# 病史特点-10.txtoriginal.txt
# 病史特点-228.txt
# 病史特点-214.txt
# 病史特点-200.txt
# 病史特点-144.txtoriginal.txt
# 病史特点-202.txtoriginal.txt
# 病史特点-299.txtoriginal.txt
# 病史特点-179.txtoriginal.txt
# 病史特点-3.txt
# 病史特点-5.txtoriginal.txt
# 病史特点-57.txtoriginal.txt
# 病史特点-84.txtoriginal.txt
# 病史特点-1.txt
# 病史特点-22.txtoriginal.txt
# 病史特点-131.txtoriginal.txt
# 病史特点-277.txtoriginal.txt
# 病史特点-216.txt
# 病史特点-197.txtoriginal.txt
# 病史特点-202.txt
# 病史特点-58.txtoriginal.txt
# 病史特点-65.txtoriginal.txt
# 病史特点-176.txtoriginal.txt
# 病史特点-296.txtoriginal.txt
# 病史特点-160.txt
# 病史特点-174.txt
# 病史特点-36.txt
# 病史特点-230.txtoriginal.txt
# 病史特点-22.txt
# 病史特点-148.txt
# 病史特点-23.txt
# 病史特点-214.txtoriginal.txt
# 病史特点-149.txt
# 病史特点-37.txt
# 病史特点-175.txt
# 病史特点-161.txt
# 病史特点-229.txtoriginal.txt
# 病史特点-152.txtoriginal.txt
# 病史特点-41.txtoriginal.txt
# 病史特点-203.txt
# 病史特点-128.txtoriginal.txt
# 病史特点-253.txtoriginal.txt
# 病史特点-217.txt
# 病史特点-115.txtoriginal.txt
# 病史特点-4.txt
# 病史特点-189.txtoriginal.txt
# 病史特点-269.txtoriginal.txt
# 病史特点-112.txtoriginal.txt
# 病史特点-254.txtoriginal.txt
# 病史特点-213.txt
# 病史特点-207.txt
# 病史特点-46.txtoriginal.txt
# 病史特点-155.txtoriginal.txt
# 病史特点-33.txt
# 病史特点-159.txt
# 病史特点-27.txt
# 病史特点-288.txtoriginal.txt
# 病史特点-168.txtoriginal.txt
# 病史特点-165.txt
# 病史特点-171.txt
# 病史特点-213.txtoriginal.txt
# 病史特点-170.txt
# 病史特点-237.txtoriginal.txt
# 病史特点-164.txt
# 病史特点-26.txt
# 病史特点-32.txt
# 病史特点-158.txt
# 病史特点-291.txtoriginal.txt
# 病史特点-171.txtoriginal.txt
# 病史特点-62.txtoriginal.txt
# 病史特点-206.txt
# 病史特点-212.txt
# 病史特点-190.txtoriginal.txt
# 病史特点-270.txtoriginal.txt
# 病史特点-136.txtoriginal.txt
# 病史特点-25.txtoriginal.txt
# 病史特点-5.txt
# 病史特点-18.txtoriginal.txt
# 病史特点-83.txtoriginal.txt
# 病史特点-50.txtoriginal.txt
# 病史特点-2.txtoriginal.txt
# 病史特点-7.txt
# 病史特点-205.txtoriginal.txt
# 病史特点-143.txtoriginal.txt
# 病史特点-238.txt
# 病史特点-238.txtoriginal.txt
# 病史特点-204.txt
# 病史特点-210.txt
# 病史特点-17.txtoriginal.txt
# 病史特点-199.txt
# 病史特点-242.txtoriginal.txt
# 病史特点-139.txtoriginal.txt
# 病史特点-24.txt
# 病史特点-30.txt
# 病史特点-18.txt
# 病史特点-172.txt
# 病史特点-104.txtoriginal.txt
# 病史特点-166.txt
# 病史特点-167.txt
# 病史特点-120.txtoriginal.txt
# 病史特点-19.txt
# 病史特点-173.txt
# 病史特点-31.txt
# 病史特点-25.txt
# 病史特点-266.txtoriginal.txt
# 病史特点-186.txtoriginal.txt
# 病史特点-198.txt
# 病史特点-95.txtoriginal.txt
# 病史特点-33.txtoriginal.txt
# 病史特点-211.txt
# 病史特点-205.txt
# 病史特点-239.txt
# 病史特点-167.txtoriginal.txt
# 病史特点-287.txtoriginal.txt
# 病史特点-221.txtoriginal.txt
# 病史特点-49.txtoriginal.txt
# 病史特点-6.txt
# 病史特点-74.txtoriginal.txt
# 病史特点-47.txtoriginal.txt
# 病史特点-154.txtoriginal.txt
# 病史特点-289.txt
# 病史特点-262.txt
# 病史特点-289.txtoriginal.txt
# 病史特点-169.txtoriginal.txt
# 病史特点-212.txtoriginal.txt
# 病史特点-276.txt
# 病史特点-81.txt
# 病史特点-188.txtoriginal.txt
# 病史特点-268.txtoriginal.txt
# 病史特点-113.txtoriginal.txt
# 病史特点-95.txt
# 病史特点-114.txt
# 病史特点-100.txt
# 病史特点-42.txt
# 病史特点-255.txtoriginal.txt
# 病史特点-128.txt
# 病史特点-56.txt
# 病史特点-57.txt
# 病史特点-43.txt
# 病史特点-191.txtoriginal.txt
# 病史特点-271.txtoriginal.txt
# 病史特点-129.txt
# 病史特点-101.txt
# 病史特点-115.txt
# 病史特点-94.txt
# 病史特点-137.txtoriginal.txt
# 病史特点-80.txt
# 病史特点-24.txtoriginal.txt
# 病史特点-19.txtoriginal.txt
# 病史特点-82.txtoriginal.txt
# 病史特点-277.txt
# 病史特点-236.txtoriginal.txt
# 病史特点-263.txt
# 病史特点-288.txt
# 病史特点-290.txtoriginal.txt
# 病史特点-170.txtoriginal.txt
# 病史特点-63.txtoriginal.txt
# 病史特点-16.txtoriginal.txt
# 病史特点-243.txtoriginal.txt
# 病史特点-138.txtoriginal.txt
# 病史特点-275.txt
# 病史特点-105.txtoriginal.txt
# 病史特点-261.txt
# 病史特点-249.txt
# 病史特点-51.txtoriginal.txt
# 病史特点-3.txtoriginal.txt
# 病史特点-96.txt
# 病史特点-204.txtoriginal.txt
# 病史特点-82.txt
# 病史特点-69.txt
# 病史特点-103.txt
# 病史特点-117.txt
# 病史特点-55.txt
# 病史特点-142.txtoriginal.txt
# 病史特点-239.txtoriginal.txt
# 病史特点-41.txt
# 病史特点-40.txt
# 病史特点-166.txtoriginal.txt
# 病史特点-54.txt
# 病史特点-286.txtoriginal.txt
# 病史特点-116.txt
# 病史特点-68.txt
# 病史特点-102.txt
# 病史特点-220.txtoriginal.txt
# 病史特点-83.txt
# 病史特点-97.txt
# 病史特点-300.txt
# 病史特点-48.txtoriginal.txt
# 病史特点-75.txtoriginal.txt
# 病史特点-248.txt
# 病史特点-121.txtoriginal.txt
# 病史特点-260.txt
# 病史特点-274.txt
# 病史特点-267.txtoriginal.txt
# 病史特点-187.txtoriginal.txt
# 病史特点-94.txtoriginal.txt
# 病史特点-32.txtoriginal.txt
# 病史特点-35.txtoriginal.txt
# 病史特点-93.txtoriginal.txt
# 病史特点-180.txtoriginal.txt
# 病史特点-260.txtoriginal.txt
# 病史特点-258.txt
# 病史特点-126.txtoriginal.txt
# 病史特点-270.txt
# 病史特点-264.txt
# 病史特点-72.txtoriginal.txt
# 病史特点-93.txt
# 病史特点-87.txt
# 病史特点-227.txtoriginal.txt
# 病史特点-50.txt
# 病史特点-44.txt
# 病史特点-281.txtoriginal.txt
# 病史特点-106.txt
# 病史特点-161.txtoriginal.txt
# 病史特点-78.txt
# 病史特点-112.txt
# 病史特点-79.txt
# 病史特点-113.txt
# 病史特点-107.txt
# 病史特点-145.txtoriginal.txt
# 病史特点-45.txt
# 病史特点-51.txt
# 病史特点-203.txtoriginal.txt
# 病史特点-298.txtoriginal.txt
# 病史特点-178.txtoriginal.txt
# 病史特点-86.txt
# 病史特点-92.txt
# 病史特点-4.txtoriginal.txt
# 病史特点-56.txtoriginal.txt
# 病史特点-265.txt
# 病史特点-271.txt
# 病史特点-259.txt
# 病史特点-102.txtoriginal.txt
# 病史特点-199.txtoriginal.txt
# 病史特点-279.txtoriginal.txt
# 病史特点-244.txtoriginal.txt
# 病史特点-11.txtoriginal.txt
# 病史特点-59.txtoriginal.txt
# 病史特点-64.txtoriginal.txt
# 病史特点-177.txtoriginal.txt
# 病史特点-297.txtoriginal.txt
# 病史特点-298.txt
# 病史特点-231.txtoriginal.txt
# 病史特点-267.txt
# 病史特点-273.txt
# 病史特点-85.txtoriginal.txt
# 病史特点-23.txtoriginal.txt
# 病史特点-84.txt
# 病史特点-90.txt
# 病史特点-130.txtoriginal.txt
# 病史特点-47.txt
# 病史特点-53.txt
# 病史特点-139.txt
# 病史特点-276.txtoriginal.txt
# 病史特点-111.txt
# 病史特点-196.txtoriginal.txt
# 病史特点-105.txt
# 病史特点-129.txtoriginal.txt
# 病史特点-104.txt
# 病史特点-110.txt
# 病史特点-252.txtoriginal.txt
# 病史特点-52.txt
# 病史特点-138.txt
# 病史特点-46.txt
# 病史特点-114.txtoriginal.txt
# 病史特点-91.txt
# 病史特点-85.txt
# 病史特点-272.txt
# 病史特点-266.txt
# 病史特点-215.txtoriginal.txt
# 病史特点-228.txtoriginal.txt
# 病史特点-153.txtoriginal.txt
# 病史特点-299.txt
# 病史特点-40.txtoriginal.txt
# 出院情况-107.txt
# 出院情况-244.txtoriginal.txt
# 出院情况-113.txt
# 出院情况-102.txtoriginal.txt
# 出院情况-279.txtoriginal.txt
# 出院情况-199.txtoriginal.txt
# 出院情况-24.txtoriginal.txt
# 出院情况-19.txtoriginal.txt
# 出院情况-82.txtoriginal.txt
# 出院情况-203.txtoriginal.txt
# 出院情况-178.txtoriginal.txt
# 出院情况-298.txtoriginal.txt
# 出院情况-259.txt
# 出院情况-271.txt
# 出院情况-93.txt
# 出院情况-265.txt
# 出院情况-87.txt
# 出院情况-145.txtoriginal.txt
# 出院情况-78.txt
# 出院情况-50.txt
# 出院情况-44.txt
# 出院情况-63.txtoriginal.txt
# 出院情况-1.txtoriginal.txt
# 出院情况-47.txtoriginal.txt
# 出院情况-45.txt
# 出院情况-51.txt
# 出院情况-161.txtoriginal.txt
# 出院情况-79.txt
# 出院情况-281.txtoriginal.txt
# 出院情况-86.txt
# 出院情况-264.txt
# 出院情况-92.txt
# 出院情况-270.txt
# 出院情况-258.txt
# 出院情况-227.txtoriginal.txt
# 出院情况-126.txtoriginal.txt
# 出院情况-112.txt
# 出院情况-260.txtoriginal.txt
# 出院情况-180.txtoriginal.txt
# 出院情况-106.txt
# 出院情况-138.txt
# 出院情况-110.txt
# 出院情况-228.txtoriginal.txt
# 出院情况-104.txt
# 出院情况-153.txtoriginal.txt
# 出院情况-215.txtoriginal.txt
# 出院情况-48.txtoriginal.txt
# 出院情况-75.txtoriginal.txt
# 出院情况-114.txtoriginal.txt
# 出院情况-266.txt
# 出院情况-84.txt
# 出院情况-272.txt
# 出院情况-90.txt
# 出院情况-299.txt
# 出院情况-129.txtoriginal.txt
# 出院情况-252.txtoriginal.txt
# 出院情况-47.txt
# 出院情况-53.txt
# 出院情况-94.txtoriginal.txt
# 出院情况-32.txtoriginal.txt
# 出院情况-16.txtoriginal.txt
# 出院情况-52.txt
# 出院情况-46.txt
# 出院情况-196.txtoriginal.txt
# 出院情况-276.txtoriginal.txt
# 出院情况-298.txt
# 出院情况-91.txt
# 出院情况-273.txt
# 出院情况-85.txt
# 出院情况-267.txt
# 出院情况-130.txtoriginal.txt
# 出院情况-51.txtoriginal.txt
# 出院情况-231.txtoriginal.txt
# 出院情况-297.txtoriginal.txt
# 出院情况-105.txt
# 出院情况-177.txtoriginal.txt
# 出院情况-111.txt
# 出院情况-139.txt
# 出院情况-115.txt
# 出院情况-101.txt
# 出院情况-129.txt
# 出院情况-170.txtoriginal.txt
# 出院情况-290.txtoriginal.txt
# 出院情况-236.txtoriginal.txt
# 出院情况-9.txtoriginal.txt
# 出院情况-56.txtoriginal.txt
# 出院情况-137.txtoriginal.txt
# 出院情况-263.txt
# 出院情况-81.txt
# 出院情况-277.txt
# 出院情况-95.txt
# 出院情况-42.txt
# 出院情况-271.txtoriginal.txt
# 出院情况-56.txt
# 出院情况-288.txt
# 出院情况-11.txtoriginal.txt
# 出院情况-35.txtoriginal.txt
# 出院情况-93.txtoriginal.txt
# 出院情况-289.txt
# 出院情况-255.txtoriginal.txt
# 出院情况-57.txt
# 出院情况-43.txt
# 出院情况-94.txt
# 出院情况-276.txt
# 出院情况-268.txtoriginal.txt
# 出院情况-188.txtoriginal.txt
# 出院情况-113.txtoriginal.txt
# 出院情况-80.txt
# 出院情况-262.txt
# 出院情况-72.txtoriginal.txt
# 出院情况-169.txtoriginal.txt
# 出院情况-289.txtoriginal.txt
# 出院情况-212.txtoriginal.txt
# 出院情况-154.txtoriginal.txt
# 出院情况-128.txt
# 出院情况-100.txt
# 出院情况-114.txt
# 出院情况-102.txt
# 出院情况-116.txt
# 出院情况-187.txtoriginal.txt
# 出院情况-267.txtoriginal.txt
# 出院情况-121.txtoriginal.txt
# 出院情况-300.txt
# 出院情况-220.txtoriginal.txt
# 出院情况-274.txt
# 出院情况-96.txt
# 出院情况-260.txt
# 出院情况-82.txt
# 出院情况-248.txt
# 出院情况-55.txt
# 出院情况-286.txtoriginal.txt
# 出院情况-41.txt
# 出院情况-166.txtoriginal.txt
# 出院情况-69.txt
# 出院情况-40.txtoriginal.txt
# 出院情况-59.txtoriginal.txt
# 出院情况-6.txtoriginal.txt
# 出院情况-64.txtoriginal.txt
# 出院情况-68.txt
# 出院情况-40.txt
# 出院情况-142.txtoriginal.txt
# 出院情况-239.txtoriginal.txt
# 出院情况-54.txt
# 出院情况-249.txt
# 出院情况-83.txt
# 出院情况-261.txt
# 出院情况-204.txtoriginal.txt
# 出院情况-97.txt
# 出院情况-275.txt
# 出院情况-85.txtoriginal.txt
# 出院情况-23.txtoriginal.txt
# 出院情况-105.txtoriginal.txt
# 出院情况-243.txtoriginal.txt
# 出院情况-138.txtoriginal.txt
# 出院情况-117.txt
# 出院情况-103.txt
# 出院情况-158.txt
# 出院情况-164.txt
# 出院情况-136.txtoriginal.txt
# 出院情况-170.txt
# 出院情况-270.txtoriginal.txt
# 出院情况-190.txtoriginal.txt
# 出院情况-10.txtoriginal.txt
# 出院情况-171.txtoriginal.txt
# 出院情况-291.txtoriginal.txt
# 出院情况-212.txt
# 出院情况-206.txt
# 出院情况-237.txtoriginal.txt
# 出院情况-33.txt
# 出院情况-27.txt
# 出院情况-8.txtoriginal.txt
# 出院情况-3.txt
# 出院情况-57.txtoriginal.txt
# 出院情况-73.txtoriginal.txt
# 出院情况-2.txt
# 出院情况-26.txt
# 出院情况-32.txt
# 出院情况-168.txtoriginal.txt
# 出院情况-288.txtoriginal.txt
# 出院情况-213.txtoriginal.txt
# 出院情况-207.txt
# 出院情况-213.txt
# 出院情况-155.txtoriginal.txt
# 出院情况-34.txtoriginal.txt
# 出院情况-92.txtoriginal.txt
# 出院情况-254.txtoriginal.txt
# 出院情况-269.txtoriginal.txt
# 出院情况-189.txtoriginal.txt
# 出院情况-171.txt
# 出院情况-112.txtoriginal.txt
# 出院情况-165.txt
# 出院情况-159.txt
# 出院情况-173.txt
# 出院情况-221.txtoriginal.txt
# 出院情况-167.txt
# 出院情况-198.txt
# 出院情况-287.txtoriginal.txt
# 出院情况-167.txtoriginal.txt
# 出院情况-41.txtoriginal.txt
# 出院情况-239.txt
# 出院情况-186.txtoriginal.txt
# 出院情况-266.txtoriginal.txt
# 出院情况-205.txt
# 出院情况-211.txt
# 出院情况-18.txt
# 出院情况-120.txtoriginal.txt
# 出院情况-24.txt
# 出院情况-30.txt
# 出院情况-84.txtoriginal.txt
# 出院情况-1.txt
# 出院情况-22.txtoriginal.txt
# 出院情况-31.txt
# 出院情况-25.txt
# 出院情况-19.txt
# 出院情况-104.txtoriginal.txt
# 出院情况-210.txt
# 出院情况-204.txt
# 出院情况-242.txtoriginal.txt
# 出院情况-139.txtoriginal.txt
# 出院情况-238.txt
# 出院情况-58.txtoriginal.txt
# 出院情况-65.txtoriginal.txt
# 出院情况-7.txtoriginal.txt
# 出院情况-143.txtoriginal.txt
# 出院情况-238.txtoriginal.txt
# 出院情况-199.txt
# 出院情况-166.txt
# 出院情况-172.txt
# 出院情况-205.txtoriginal.txt
# 出院情况-176.txt
# 出院情况-162.txt
# 出院情况-202.txtoriginal.txt
# 出院情况-179.txtoriginal.txt
# 出院情况-299.txtoriginal.txt
# 出院情况-189.txt
# 出院情况-144.txtoriginal.txt
# 出院情况-62.txtoriginal.txt
# 出院情况-200.txt
# 出院情况-245.txtoriginal.txt
# 出院情况-214.txt
# 出院情况-228.txt
# 出院情况-21.txt
# 出院情况-103.txtoriginal.txt
# 出院情况-278.txtoriginal.txt
# 出院情况-198.txtoriginal.txt
# 出院情况-35.txt
# 出院情况-5.txt
# 出院情况-25.txtoriginal.txt
# 出院情况-18.txtoriginal.txt
# 出院情况-83.txtoriginal.txt
# 出院情况-4.txt
# 出院情况-34.txt
# 出院情况-127.txtoriginal.txt
# 出院情况-20.txt
# 出院情况-229.txt
# 出院情况-261.txtoriginal.txt
# 出院情况-181.txtoriginal.txt
# 出院情况-215.txt
# 出院情况-201.txt
# 出院情况-46.txtoriginal.txt
# 出院情况-160.txtoriginal.txt
# 出院情况-280.txtoriginal.txt
# 出院情况-188.txt
# 出院情况-226.txtoriginal.txt
# 出院情况-163.txt
# 出院情况-177.txt
# 出院情况-161.txt
# 出院情况-175.txt
# 出院情况-115.txtoriginal.txt
# 出院情况-149.txt
# 出院情况-128.txtoriginal.txt
# 出院情况-253.txtoriginal.txt
# 出院情况-95.txtoriginal.txt
# 出院情况-33.txtoriginal.txt
# 出院情况-217.txt
# 出院情况-229.txtoriginal.txt
# 出院情况-152.txtoriginal.txt
# 出院情况-203.txt
# 出院情况-36.txt
# 出院情况-214.txtoriginal.txt
# 出院情况-22.txt
# 出院情况-49.txtoriginal.txt
# 出院情况-6.txt
# 出院情况-74.txtoriginal.txt
# 出院情况-50.txtoriginal.txt
# 出院情况-7.txt
# 出院情况-23.txt
# 出院情况-37.txt
# 出院情况-230.txtoriginal.txt
# 出院情况-296.txtoriginal.txt
# 出院情况-202.txt
# 出院情况-176.txtoriginal.txt
# 出院情况-216.txt
# 出院情况-17.txtoriginal.txt
# 出院情况-197.txtoriginal.txt
# 出院情况-277.txtoriginal.txt
# 出院情况-148.txt
# 出院情况-131.txtoriginal.txt
# 出院情况-174.txt
# 出院情况-160.txt
# 出院情况-179.txt
# 出院情况-145.txt
# 出院情况-151.txt
# 出院情况-71.txtoriginal.txt
# 出院情况-186.txt
# 出院情况-192.txt
# 出院情况-157.txtoriginal.txt
# 出院情况-211.txtoriginal.txt
# 出院情况-90.txtoriginal.txt
# 出院情况-233.txt
# 出院情况-227.txt
# 出院情况-36.txtoriginal.txt
# 出院情况-12.txt
# 出院情况-110.txtoriginal.txt
# 出院情况-256.txtoriginal.txt
# 出院情况-109.txtoriginal.txt
# 出院情况-192.txtoriginal.txt
# 出院情况-272.txtoriginal.txt
# 出院情况-300.txtoriginal.txt
# 出院情况-134.txtoriginal.txt
# 出院情况-13.txt
# 出院情况-12.txtoriginal.txt
# 出院情况-89.txtoriginal.txt
# 出院情况-226.txt
# 出院情况-232.txt
# 出院情况-235.txtoriginal.txt
# 出院情况-208.txtoriginal.txt
# 出院情况-293.txtoriginal.txt
# 出院情况-173.txtoriginal.txt
# 出院情况-193.txt
# 出院情况-187.txt
# 出院情况-55.txtoriginal.txt
# 出院情况-150.txt
# 出院情况-68.txtoriginal.txt
# 出院情况-144.txt
# 出院情况-178.txt
# 出院情况-152.txt
# 出院情况-146.txt
# 出院情况-20.txtoriginal.txt
# 出院情况-86.txtoriginal.txt
# 出院情况-185.txt
# 出院情况-240.txtoriginal.txt
# 出院情况-106.txtoriginal.txt
# 出院情况-67.txtoriginal.txt
# 出院情况-218.txt
# 出院情况-224.txt
# 出院情况-230.txt
# 出院情况-5.txtoriginal.txt
# 出院情况-39.txt
# 出院情况-11.txt
# 出院情况-9.txt
# 出院情况-207.txtoriginal.txt
# 出院情况-141.txtoriginal.txt
# 出院情况-165.txtoriginal.txt
# 出院情况-285.txtoriginal.txt
# 出院情况-223.txtoriginal.txt
# 出院情况-8.txt
# 出院情况-158.txtoriginal.txt
# 出院情况-10.txt
# 出院情况-38.txt
# 出院情况-231.txt
# 出院情况-225.txt
# 出院情况-43.txtoriginal.txt
# 出院情况-219.txt
# 出院情况-122.txtoriginal.txt
# 出院情况-259.txtoriginal.txt
# 出院情况-264.txtoriginal.txt
# 出院情况-184.txtoriginal.txt
# 出院情况-184.txt
# 出院情况-39.txtoriginal.txt
# 出院情况-190.txt
# 出院情况-147.txt
# 出院情况-153.txt
# 出院情况-157.txt
# 出院情况-143.txt
# 出院情况-98.txtoriginal.txt
# 出院情况-194.txt
# 出院情况-180.txt
# 出院情况-183.txtoriginal.txt
# 出院情况-263.txtoriginal.txt
# 出院情况-118.txtoriginal.txt
# 出院情况-125.txtoriginal.txt
# 出院情况-221.txt
# 出院情况-44.txtoriginal.txt
# 出院情况-235.txt
# 出院情况-209.txt
# 出院情况-79.txtoriginal.txt
# 出院情况-14.txt
# 出院情况-28.txt
# 出院情况-224.txtoriginal.txt
# 出院情况-282.txtoriginal.txt
# 出院情况-162.txtoriginal.txt
# 出院情况-219.txtoriginal.txt
# 出院情况-146.txtoriginal.txt
# 出院情况-200.txtoriginal.txt
# 出院情况-29.txt
# 出院情况-15.txt
# 出院情况-2.txtoriginal.txt
# 出院情况-208.txt
# 出院情况-234.txt
# 出院情况-60.txtoriginal.txt
# 出院情况-220.txt
# 出院情况-101.txtoriginal.txt
# 出院情况-247.txtoriginal.txt
# 出院情况-81.txtoriginal.txt
# 出院情况-181.txt
# 出院情况-195.txt
# 出院情况-27.txtoriginal.txt
# 出院情况-142.txt
# 出院情况-156.txt
# 出院情况-140.txt
# 出院情况-154.txt
# 出院情况-168.txt
# 出院情况-183.txt
# 出院情况-197.txt
# 出院情况-52.txtoriginal.txt
# 出院情况-174.txtoriginal.txt
# 出院情况-294.txtoriginal.txt
# 出院情况-149.txtoriginal.txt
# 出院情况-232.txtoriginal.txt
# 出院情况-236.txt
# 出院情况-222.txt
# 出院情况-28.txtoriginal.txt
# 出院情况-17.txt
# 出院情况-15.txtoriginal.txt
# 出院情况-248.txtoriginal.txt
# 出院情况-133.txtoriginal.txt
# 出院情况-275.txtoriginal.txt
# 出院情况-195.txtoriginal.txt
# 出院情况-251.txtoriginal.txt
# 出院情况-117.txtoriginal.txt
# 出院情况-31.txtoriginal.txt
# 出院情况-16.txt
# 出院情况-223.txt
# 出院情况-237.txt
# 出院情况-97.txtoriginal.txt
# 出院情况-216.txtoriginal.txt
# 出院情况-150.txtoriginal.txt
# 出院情况-76.txtoriginal.txt
# 出院情况-196.txt
# 出院情况-182.txt
# 出院情况-169.txt
# 出院情况-155.txt
# 出院情况-141.txt
# 出院情况-45.txtoriginal.txt
# 出院情况-126.txt
# 出院情况-132.txt
# 出院情况-78.txtoriginal.txt
# 出院情况-225.txtoriginal.txt
# 出院情况-283.txtoriginal.txt
# 出院情况-163.txtoriginal.txt
# 出院情况-218.txtoriginal.txt
# 出院情况-99.txtoriginal.txt
# 出院情况-278.txt
# 出院情况-250.txt
# 出院情况-244.txt
# 出院情况-59.txt
# 出院情况-71.txt
# 出院情况-293.txt
# 出院情况-65.txt
# 出院情况-287.txt
# 出院情况-182.txtoriginal.txt
# 出院情况-262.txtoriginal.txt
# 出院情况-119.txtoriginal.txt
# 出院情况-124.txtoriginal.txt
# 出院情况-100.txtoriginal.txt
# 出院情况-246.txtoriginal.txt
# 出院情况-286.txt
# 出院情况-64.txt
# 出院情况-292.txt
# 出院情况-70.txt
# 出院情况-58.txt
# 出院情况-80.txtoriginal.txt
# 出院情况-245.txt
# 出院情况-251.txt
# 出院情况-26.txtoriginal.txt
# 出院情况-279.txt
# 出院情况-147.txtoriginal.txt
# 出院情况-201.txtoriginal.txt
# 出院情况-133.txt
# 出院情况-61.txtoriginal.txt
# 出院情况-127.txt
# 出院情况-3.txtoriginal.txt
# 出院情况-119.txt
# 出院情况-131.txt
# 出院情况-125.txt
# 出院情况-29.txtoriginal.txt
# 出院情况-14.txtoriginal.txt
# 出院情况-249.txtoriginal.txt
# 出院情况-132.txtoriginal.txt
# 出院情况-274.txtoriginal.txt
# 出院情况-194.txtoriginal.txt
# 出院情况-99.txt
# 出院情况-247.txt
# 出院情况-253.txt
# 出院情况-53.txtoriginal.txt
# 出院情况-66.txt
# 出院情况-284.txt
# 出院情况-72.txt
# 出院情况-290.txt
# 出院情况-175.txtoriginal.txt
# 出院情况-295.txtoriginal.txt
# 出院情况-148.txtoriginal.txt
# 出院情况-233.txtoriginal.txt
# 出院情况-217.txtoriginal.txt
# 出院情况-151.txtoriginal.txt
# 出院情况-291.txt
# 出院情况-73.txt
# 出院情况-285.txt
# 出院情况-67.txt
# 出院情况-77.txtoriginal.txt
# 出院情况-252.txt
# 出院情况-246.txt
# 出院情况-98.txt
# 出院情况-250.txtoriginal.txt
# 出院情况-116.txtoriginal.txt
# 出院情况-30.txtoriginal.txt
# 出院情况-124.txt
# 出院情况-96.txtoriginal.txt
# 出院情况-130.txt
# 出院情况-118.txt
# 出院情况-134.txt
# 出院情况-120.txt
# 出院情况-108.txt
# 出院情况-91.txtoriginal.txt
# 出院情况-37.txtoriginal.txt
# 出院情况-111.txtoriginal.txt
# 出院情况-257.txtoriginal.txt
# 出院情况-242.txt
# 出院情况-256.txt
# 出院情况-88.txt
# 出院情况-70.txtoriginal.txt
# 出院情况-63.txt
# 出院情况-281.txt
# 出院情况-77.txt
# 出院情况-295.txt
# 出院情况-156.txtoriginal.txt
# 出院情况-210.txtoriginal.txt
# 出院情况-234.txtoriginal.txt
# 出院情况-209.txtoriginal.txt
# 出院情况-292.txtoriginal.txt
# 出院情况-172.txtoriginal.txt
# 出院情况-294.txt
# 出院情况-76.txt
# 出院情况-54.txtoriginal.txt
# 出院情况-280.txt
# 出院情况-62.txt
# 出院情况-89.txt
# 出院情况-257.txt
# 出院情况-69.txtoriginal.txt
# 出院情况-243.txt
# 出院情况-108.txtoriginal.txt
# 出院情况-193.txtoriginal.txt
# 出院情况-273.txtoriginal.txt
# 出院情况-135.txtoriginal.txt
# 出院情况-13.txtoriginal.txt
# 出院情况-88.txtoriginal.txt
# 出院情况-109.txt
# 出院情况-121.txt
# 出院情况-135.txt
# 出院情况-123.txt
# 出院情况-4.txtoriginal.txt
# 出院情况-137.txt
# 出院情况-66.txtoriginal.txt
# 出院情况-206.txtoriginal.txt
# 出院情况-140.txtoriginal.txt
# 出院情况-255.txt
# 出院情况-241.txt
# 出院情况-21.txtoriginal.txt
# 出院情况-269.txt
# 出院情况-87.txtoriginal.txt
# 出院情况-74.txt
# 出院情况-296.txt
# 出院情况-60.txt
# 出院情况-282.txt
# 出院情况-48.txt
# 出院情况-241.txtoriginal.txt
# 出院情况-107.txtoriginal.txt
# 出院情况-123.txtoriginal.txt
# 出院情况-258.txtoriginal.txt
# 出院情况-265.txtoriginal.txt
# 出院情况-185.txtoriginal.txt
# 出院情况-49.txt
# 出院情况-283.txt
# 出院情况-61.txt
# 出院情况-38.txtoriginal.txt
# 出院情况-297.txt
# 出院情况-75.txt
# 出院情况-268.txt
# 出院情况-240.txt
# 出院情况-254.txt
# 出院情况-164.txtoriginal.txt
# 出院情况-284.txtoriginal.txt
# 出院情况-222.txtoriginal.txt
# 出院情况-159.txtoriginal.txt
# 出院情况-42.txtoriginal.txt
# 出院情况-136.txt
# 出院情况-122.txt
# 一般项目-112.txtoriginal.txt
# 一般项目-189.txtoriginal.txt
# 一般项目-269.txtoriginal.txt
# 一般项目-47.txtoriginal.txt
# 一般项目-254.txtoriginal.txt
# 一般项目-100.txt
# 一般项目-114.txt
# 一般项目-128.txt
# 一般项目-89.txt
# 一般项目-155.txtoriginal.txt
# 一般项目-213.txtoriginal.txt
# 一般项目-288.txtoriginal.txt
# 一般项目-168.txtoriginal.txt
# 一般项目-76.txt
# 一般项目-62.txt
# 一般项目-289.txt
# 一般项目-276.txt
# 一般项目-262.txt
# 一般项目-263.txt
# 一般项目-277.txt
# 一般项目-288.txt
# 一般项目-63.txt
# 一般项目-77.txt
# 一般项目-24.txtoriginal.txt
# 一般项目-237.txtoriginal.txt
# 一般项目-19.txtoriginal.txt
# 一般项目-291.txtoriginal.txt
# 一般项目-171.txtoriginal.txt
# 一般项目-82.txtoriginal.txt
# 一般项目-88.txt
# 一般项目-129.txt
# 一般项目-115.txt
# 一般项目-101.txt
# 一般项目-190.txtoriginal.txt
# 一般项目-270.txtoriginal.txt
# 一般项目-63.txtoriginal.txt
# 一般项目-136.txtoriginal.txt
# 一般项目-205.txtoriginal.txt
# 一般项目-16.txtoriginal.txt
# 一般项目-238.txtoriginal.txt
# 一般项目-143.txtoriginal.txt
# 一般项目-117.txt
# 一般项目-103.txt
# 一般项目-139.txtoriginal.txt
# 一般项目-51.txtoriginal.txt
# 一般项目-242.txtoriginal.txt
# 一般项目-104.txtoriginal.txt
# 一般项目-49.txt
# 一般项目-61.txt
# 一般项目-75.txt
# 一般项目-261.txt
# 一般项目-275.txt
# 一般项目-249.txt
# 一般项目-248.txt
# 一般项目-274.txt
# 一般项目-260.txt
# 一般项目-74.txt
# 一般项目-60.txt
# 一般项目-48.txt
# 一般项目-120.txtoriginal.txt
# 一般项目-48.txtoriginal.txt
# 一般项目-266.txtoriginal.txt
# 一般项目-186.txtoriginal.txt
# 一般项目-75.txtoriginal.txt
# 一般项目-102.txt
# 一般项目-116.txt
# 一般项目-2.txtoriginal.txt
# 一般项目-167.txtoriginal.txt
# 一般项目-287.txtoriginal.txt
# 一般项目-94.txtoriginal.txt
# 一般项目-300.txt
# 一般项目-32.txtoriginal.txt
# 一般项目-221.txtoriginal.txt
# 一般项目-226.txtoriginal.txt
# 一般项目-35.txtoriginal.txt
# 一般项目-93.txtoriginal.txt
# 一般项目-280.txtoriginal.txt
# 一般项目-160.txtoriginal.txt
# 一般项目-5.txtoriginal.txt
# 一般项目-112.txt
# 一般项目-106.txt
# 一般项目-72.txtoriginal.txt
# 一般项目-181.txtoriginal.txt
# 一般项目-261.txtoriginal.txt
# 一般项目-64.txt
# 一般项目-127.txtoriginal.txt
# 一般项目-70.txt
# 一般项目-58.txt
# 一般项目-258.txt
# 一般项目-264.txt
# 一般项目-270.txt
# 一般项目-271.txt
# 一般项目-265.txt
# 一般项目-259.txt
# 一般项目-59.txt
# 一般项目-198.txtoriginal.txt
# 一般项目-71.txt
# 一般项目-278.txtoriginal.txt
# 一般项目-65.txt
# 一般项目-103.txtoriginal.txt
# 一般项目-245.txtoriginal.txt
# 一般项目-56.txtoriginal.txt
# 一般项目-107.txt
# 一般项目-113.txt
# 一般项目-144.txtoriginal.txt
# 一般项目-11.txtoriginal.txt
# 一般项目-299.txtoriginal.txt
# 一般项目-179.txtoriginal.txt
# 一般项目-202.txtoriginal.txt
# 一般项目-131.txtoriginal.txt
# 一般项目-59.txtoriginal.txt
# 一般项目-64.txtoriginal.txt
# 一般项目-277.txtoriginal.txt
# 一般项目-197.txtoriginal.txt
# 一般项目-139.txt
# 一般项目-105.txt
# 一般项目-111.txt
# 一般项目-85.txtoriginal.txt
# 一般项目-176.txtoriginal.txt
# 一般项目-296.txtoriginal.txt
# 一般项目-98.txt
# 一般项目-73.txt
# 一般项目-230.txtoriginal.txt
# 一般项目-23.txtoriginal.txt
# 一般项目-67.txt
# 一般项目-298.txt
# 一般项目-273.txt
# 一般项目-267.txt
# 一般项目-266.txt
# 一般项目-272.txt
# 一般项目-299.txt
# 一般项目-66.txt
# 一般项目-214.txtoriginal.txt
# 一般项目-72.txt
# 一般项目-99.txt
# 一般项目-152.txtoriginal.txt
# 一般项目-229.txtoriginal.txt
# 一般项目-110.txt
# 一般项目-104.txt
# 一般项目-138.txt
# 一般项目-253.txtoriginal.txt
# 一般项目-128.txtoriginal.txt
# 一般项目-40.txtoriginal.txt
# 一般项目-115.txtoriginal.txt
# 一般项目-73.txtoriginal.txt
# 一般项目-180.txtoriginal.txt
# 一般项目-260.txtoriginal.txt
# 一般项目-126.txtoriginal.txt
# 一般项目-188.txt
# 一般项目-163.txt
# 一般项目-177.txt
# 一般项目-227.txtoriginal.txt
# 一般项目-34.txtoriginal.txt
# 一般项目-29.txt
# 一般项目-92.txtoriginal.txt
# 一般项目-281.txtoriginal.txt
# 一般项目-161.txtoriginal.txt
# 一般项目-15.txt
# 一般项目-4.txtoriginal.txt
# 一般项目-3.txt
# 一般项目-215.txt
# 一般项目-201.txt
# 一般项目-229.txt
# 一般项目-228.txt
# 一般项目-200.txt
# 一般项目-214.txt
# 一般项目-2.txt
# 一般项目-14.txt
# 一般项目-145.txtoriginal.txt
# 一般项目-28.txt
# 一般项目-298.txtoriginal.txt
# 一般项目-10.txtoriginal.txt
# 一般项目-178.txtoriginal.txt
# 一般项目-203.txtoriginal.txt
# 一般项目-176.txt
# 一般项目-162.txt
# 一般项目-189.txt
# 一般项目-199.txtoriginal.txt
# 一般项目-279.txtoriginal.txt
# 一般项目-102.txtoriginal.txt
# 一般项目-244.txtoriginal.txt
# 一般项目-57.txtoriginal.txt
# 一般项目-84.txtoriginal.txt
# 一般项目-177.txtoriginal.txt
# 一般项目-297.txtoriginal.txt
# 一般项目-231.txtoriginal.txt
# 一般项目-22.txtoriginal.txt
# 一般项目-174.txt
# 一般项目-160.txt
# 一般项目-148.txt
# 一般项目-130.txtoriginal.txt
# 一般项目-58.txtoriginal.txt
# 一般项目-65.txtoriginal.txt
# 一般项目-276.txtoriginal.txt
# 一般项目-196.txtoriginal.txt
# 一般项目-16.txt
# 一般项目-202.txt
# 一般项目-216.txt
# 一般项目-217.txt
# 一般项目-203.txt
# 一般项目-1.txt
# 一般项目-17.txt
# 一般项目-252.txtoriginal.txt
# 一般项目-129.txtoriginal.txt
# 一般项目-41.txtoriginal.txt
# 一般项目-114.txtoriginal.txt
# 一般项目-149.txt
# 一般项目-161.txt
# 一般项目-175.txt
# 一般项目-215.txtoriginal.txt
# 一般项目-153.txtoriginal.txt
# 一般项目-228.txtoriginal.txt
# 一般项目-154.txtoriginal.txt
# 一般项目-212.txtoriginal.txt
# 一般项目-289.txtoriginal.txt
# 一般项目-169.txtoriginal.txt
# 一般项目-159.txt
# 一般项目-171.txt
# 一般项目-165.txt
# 一般项目-113.txtoriginal.txt
# 一般项目-188.txtoriginal.txt
# 一般项目-268.txtoriginal.txt
# 一般项目-46.txtoriginal.txt
# 一般项目-13.txt
# 一般项目-255.txtoriginal.txt
# 一般项目-5.txt
# 一般项目-207.txt
# 一般项目-213.txt
# 一般项目-212.txt
# 一般项目-206.txt
# 一般项目-4.txt
# 一般项目-12.txt
# 一般项目-191.txtoriginal.txt
# 一般项目-271.txtoriginal.txt
# 一般项目-62.txtoriginal.txt
# 一般项目-137.txtoriginal.txt
# 一般项目-164.txt
# 一般项目-170.txt
# 一般项目-158.txt
# 一般项目-25.txtoriginal.txt
# 一般项目-236.txtoriginal.txt
# 一般项目-290.txtoriginal.txt
# 一般项目-18.txtoriginal.txt
# 一般项目-170.txtoriginal.txt
# 一般项目-83.txtoriginal.txt
# 一般项目-138.txtoriginal.txt
# 一般项目-50.txtoriginal.txt
# 一般项目-243.txtoriginal.txt
# 一般项目-105.txtoriginal.txt
# 一般项目-199.txt
# 一般项目-166.txt
# 一般项目-172.txt
# 一般项目-204.txtoriginal.txt
# 一般项目-17.txtoriginal.txt
# 一般项目-239.txtoriginal.txt
# 一般项目-10.txt
# 一般项目-142.txtoriginal.txt
# 一般项目-38.txt
# 一般项目-6.txt
# 一般项目-238.txt
# 一般项目-210.txt
# 一般项目-204.txt
# 一般项目-205.txt
# 一般项目-211.txt
# 一般项目-239.txt
# 一般项目-3.txtoriginal.txt
# 一般项目-7.txt
# 一般项目-39.txt
# 一般项目-166.txtoriginal.txt
# 一般项目-286.txtoriginal.txt
# 一般项目-95.txtoriginal.txt
# 一般项目-11.txt
# 一般项目-33.txtoriginal.txt
# 一般项目-220.txtoriginal.txt
# 一般项目-173.txt
# 一般项目-167.txt
# 一般项目-198.txt
# 一般项目-121.txtoriginal.txt
# 一般项目-49.txtoriginal.txt
# 一般项目-267.txtoriginal.txt
# 一般项目-187.txtoriginal.txt
# 一般项目-74.txtoriginal.txt
# 一般项目-181.txt
# 一般项目-195.txt
# 一般项目-12.txtoriginal.txt
# 一般项目-89.txtoriginal.txt
# 一般项目-201.txtoriginal.txt
# 一般项目-142.txt
# 一般项目-156.txt
# 一般项目-147.txtoriginal.txt
# 一般项目-34.txt
# 一般项目-20.txt
# 一般项目-246.txtoriginal.txt
# 一般项目-55.txtoriginal.txt
# 一般项目-234.txt
# 一般项目-100.txtoriginal.txt
# 一般项目-220.txt
# 一般项目-68.txtoriginal.txt
# 一般项目-208.txt
# 一般项目-209.txt
# 一般项目-221.txt
# 一般项目-124.txtoriginal.txt
# 一般项目-235.txt
# 一般项目-119.txtoriginal.txt
# 一般项目-71.txtoriginal.txt
# 一般项目-262.txtoriginal.txt
# 一般项目-182.txtoriginal.txt
# 一般项目-21.txt
# 一般项目-35.txt
# 一般项目-218.txtoriginal.txt
# 一般项目-90.txtoriginal.txt
# 一般项目-163.txtoriginal.txt
# 一般项目-283.txtoriginal.txt
# 一般项目-157.txt
# 一般项目-143.txt
# 一般项目-225.txtoriginal.txt
# 一般项目-36.txtoriginal.txt
# 一般项目-194.txt
# 一般项目-180.txt
# 一般项目-6.txtoriginal.txt
# 一般项目-196.txt
# 一般项目-182.txt
# 一般项目-116.txtoriginal.txt
# 一般项目-155.txt
# 一般项目-141.txt
# 一般项目-169.txt
# 一般项目-250.txtoriginal.txt
# 一般项目-43.txtoriginal.txt
# 一般项目-9.txtoriginal.txt
# 一般项目-23.txt
# 一般项目-37.txt
# 一般项目-39.txtoriginal.txt
# 一般项目-151.txtoriginal.txt
# 一般项目-9.txt
# 一般项目-223.txt
# 一般项目-237.txt
# 一般项目-217.txtoriginal.txt
# 一般项目-236.txt
# 一般项目-233.txtoriginal.txt
# 一般项目-20.txtoriginal.txt
# 一般项目-148.txtoriginal.txt
# 一般项目-222.txt
# 一般项目-8.txt
# 一般项目-86.txtoriginal.txt
# 一般项目-295.txtoriginal.txt
# 一般项目-175.txtoriginal.txt
# 一般项目-36.txt
# 一般项目-22.txt
# 一般项目-67.txtoriginal.txt
# 一般项目-168.txt
# 一般项目-194.txtoriginal.txt
# 一般项目-274.txtoriginal.txt
# 一般项目-140.txt
# 一般项目-154.txt
# 一般项目-132.txtoriginal.txt
# 一般项目-249.txtoriginal.txt
# 一般项目-183.txt
# 一般项目-197.txt
# 一般项目-193.txt
# 一般项目-135.txtoriginal.txt
# 一般项目-187.txt
# 一般项目-178.txt
# 一般项目-273.txtoriginal.txt
# 一般项目-150.txt
# 一般项目-193.txtoriginal.txt
# 一般项目-108.txtoriginal.txt
# 一般项目-144.txt
# 一般项目-60.txtoriginal.txt
# 一般项目-26.txt
# 一般项目-32.txt
# 一般项目-172.txtoriginal.txt
# 一般项目-292.txtoriginal.txt
# 一般项目-81.txtoriginal.txt
# 一般项目-209.txtoriginal.txt
# 一般项目-27.txtoriginal.txt
# 一般项目-234.txtoriginal.txt
# 一般项目-226.txt
# 一般项目-232.txt
# 一般项目-233.txt
# 一般项目-227.txt
# 一般项目-210.txtoriginal.txt
# 一般项目-98.txtoriginal.txt
# 一般项目-156.txtoriginal.txt
# 一般项目-33.txt
# 一般项目-27.txt
# 一般项目-145.txt
# 一般项目-44.txtoriginal.txt
# 一般项目-257.txtoriginal.txt
# 一般项目-151.txt
# 一般项目-179.txt
# 一般项目-186.txt
# 一般项目-111.txtoriginal.txt
# 一般项目-79.txtoriginal.txt
# 一般项目-192.txt
# 一般项目-1.txtoriginal.txt
# 一般项目-31.txtoriginal.txt
# 一般项目-184.txt
# 一般项目-159.txtoriginal.txt
# 一般项目-190.txt
# 一般项目-222.txtoriginal.txt
# 一般项目-284.txtoriginal.txt
# 一般项目-164.txtoriginal.txt
# 一般项目-147.txt
# 一般项目-153.txt
# 一般项目-97.txtoriginal.txt
# 一般项目-31.txt
# 一般项目-25.txt
# 一般项目-19.txt
# 一般项目-185.txtoriginal.txt
# 一般项目-265.txtoriginal.txt
# 一般项目-76.txtoriginal.txt
# 一般项目-258.txtoriginal.txt
# 一般项目-219.txt
# 一般项目-123.txtoriginal.txt
# 一般项目-231.txt
# 一般项目-225.txt
# 一般项目-224.txt
# 一般项目-230.txt
# 一般项目-218.txt
# 一般项目-107.txtoriginal.txt
# 一般项目-52.txtoriginal.txt
# 一般项目-241.txtoriginal.txt
# 一般项目-18.txt
# 一般项目-24.txt
# 一般项目-30.txt
# 一般项目-152.txt
# 一般项目-28.txtoriginal.txt
# 一般项目-140.txtoriginal.txt
# 一般项目-146.txt
# 一般项目-191.txt
# 一般项目-206.txtoriginal.txt
# 一般项目-15.txtoriginal.txt
# 一般项目-185.txt
# 一般项目-173.txtoriginal.txt
# 一般项目-293.txtoriginal.txt
# 一般项目-208.txtoriginal.txt
# 一般项目-80.txtoriginal.txt
# 一般项目-121.txt
# 一般项目-135.txt
# 一般项目-26.txtoriginal.txt
# 一般项目-109.txt
# 一般项目-235.txtoriginal.txt
# 一般项目-94.txt
# 一般项目-80.txt
# 一般项目-57.txt
# 一般项目-43.txt
# 一般项目-294.txt
# 一般项目-134.txtoriginal.txt
# 一般项目-280.txt
# 一般项目-300.txtoriginal.txt
# 一般项目-272.txtoriginal.txt
# 一般项目-257.txt
# 一般项目-192.txtoriginal.txt
# 一般项目-109.txtoriginal.txt
# 一般项目-243.txt
# 一般项目-61.txtoriginal.txt
# 一般项目-45.txtoriginal.txt
# 一般项目-242.txt
# 一般项目-256.txtoriginal.txt
# 一般项目-256.txt
# 一般项目-110.txtoriginal.txt
# 一般项目-78.txtoriginal.txt
# 一般项目-281.txt
# 一般项目-295.txt
# 一般项目-42.txt
# 一般项目-56.txt
# 一般项目-81.txt
# 一般项目-95.txt
# 一般项目-99.txtoriginal.txt
# 一般项目-108.txt
# 一般项目-211.txtoriginal.txt
# 一般项目-134.txt
# 一般项目-120.txt
# 一般项目-157.txtoriginal.txt
# 一般项目-184.txtoriginal.txt
# 一般项目-264.txtoriginal.txt
# 一般项目-77.txtoriginal.txt
# 一般项目-136.txt
# 一般项目-122.txt
# 一般项目-259.txtoriginal.txt
# 一般项目-122.txtoriginal.txt
# 一般项目-83.txt
# 一般项目-97.txt
# 一般项目-68.txt
# 一般项目-40.txt
# 一般项目-54.txt
# 一般项目-30.txtoriginal.txt
# 一般项目-283.txt
# 一般项目-158.txtoriginal.txt
# 一般项目-223.txtoriginal.txt
# 一般项目-297.txt
# 一般项目-240.txt
# 一般项目-285.txtoriginal.txt
# 一般项目-165.txtoriginal.txt
# 一般项目-96.txtoriginal.txt
# 一般项目-254.txt
# 一般项目-268.txt
# 一般项目-269.txt
# 一般项目-255.txt
# 一般项目-29.txtoriginal.txt
# 一般项目-241.txt
# 一般项目-141.txtoriginal.txt
# 一般项目-207.txtoriginal.txt
# 一般项目-296.txt
# 一般项目-282.txt
# 一般项目-14.txtoriginal.txt
# 一般项目-55.txt
# 一般项目-41.txt
# 一般项目-69.txt
# 一般项目-96.txt
# 一般项目-82.txt
# 一般项目-106.txtoriginal.txt
# 一般项目-123.txt
# 一般项目-137.txt
# 一般项目-53.txtoriginal.txt
# 一般项目-240.txtoriginal.txt
# 一般项目-247.txtoriginal.txt
# 一般项目-54.txtoriginal.txt
# 一般项目-133.txt
# 一般项目-101.txtoriginal.txt
# 一般项目-127.txt
# 一般项目-69.txtoriginal.txt
# 一般项目-86.txt
# 一般项目-92.txt
# 一般项目-45.txt
# 一般项目-51.txt
# 一般项目-79.txt
# 一般项目-13.txtoriginal.txt
# 一般项目-200.txtoriginal.txt
# 一般项目-88.txtoriginal.txt
# 一般项目-286.txt
# 一般项目-292.txt
# 一般项目-146.txtoriginal.txt
# 一般项目-279.txt
# 一般项目-245.txt
# 一般项目-251.txt
# 一般项目-250.txt
# 一般项目-244.txt
# 一般项目-91.txtoriginal.txt
# 一般项目-219.txtoriginal.txt
# 一般项目-162.txtoriginal.txt
# 一般项目-278.txt
# 一般项目-282.txtoriginal.txt
# 一般项目-293.txt
# 一般项目-287.txt
# 一般项目-224.txtoriginal.txt
# 一般项目-37.txtoriginal.txt
# 一般项目-78.txt
# 一般项目-50.txt
# 一般项目-44.txt
# 一般项目-93.txt
# 一般项目-7.txtoriginal.txt
# 一般项目-87.txt
# 一般项目-125.txtoriginal.txt
# 一般项目-126.txt
# 一般项目-132.txt
# 一般项目-118.txtoriginal.txt
# 一般项目-70.txtoriginal.txt
# 一般项目-263.txtoriginal.txt
# 一般项目-183.txtoriginal.txt
# 一般项目-8.txtoriginal.txt
# 一般项目-38.txtoriginal.txt
# 一般项目-150.txtoriginal.txt
# 一般项目-118.txt
# 一般项目-124.txt
# 一般项目-216.txtoriginal.txt
# 一般项目-130.txt
# 一般项目-91.txt
# 一般项目-85.txt
# 一般项目-52.txt
# 一般项目-46.txt
# 一般项目-117.txtoriginal.txt
# 一般项目-291.txt
# 一般项目-285.txt
# 一般项目-251.txtoriginal.txt
# 一般项目-42.txtoriginal.txt
# 一般项目-252.txt
# 一般项目-246.txt
# 一般项目-247.txt
# 一般项目-253.txt
# 一般项目-66.txtoriginal.txt
# 一般项目-195.txtoriginal.txt
# 一般项目-275.txtoriginal.txt
# 一般项目-284.txt
# 一般项目-290.txt
# 一般项目-133.txtoriginal.txt
# 一般项目-248.txtoriginal.txt
# 一般项目-47.txt
# 一般项目-53.txt
# 一般项目-84.txt
# 一般项目-90.txt
# 一般项目-131.txt
# 一般项目-232.txtoriginal.txt
# 一般项目-21.txtoriginal.txt
# 一般项目-125.txt
# 一般项目-149.txtoriginal.txt
# 一般项目-119.txt
# 一般项目-87.txtoriginal.txt
# 一般项目-294.txtoriginal.txt
# 一般项目-174.txtoriginal.txt

# %% [markdown]
# # 文本特征工程

# %% [markdown]
# 要使用CRF算法对每个字进行标注，就需要获取每个字对应的特征。就需要对文本进行特征工程，这一部分就是构建一句话中每个字的特征。

# %%
#中文分词时最常用的包是jieba。但我们本次的数据集是专门针对医疗领域的，这里选用了一个在细分领域上表现更好的库pkuseg
import jieba
#import pkuseg
#将model_name设置为'medicine'以加载医疗领域的模型。第一次执行此代码时会自动下载医疗领域对应的模型，这可能需要一些时间。
#设置postag为True会在分词的同时进行词性标注
seg = pkuseg.pkuseg(model_name='medicine',postag=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-3ef6299eda86> in <module>
#       4 #将model_name设置为'medicine'以加载医疗领域的模型。第一次执行此代码时会自动下载医疗领域对应的模型，这可能需要一些时间。
#       5 #设置postag为True会在分词的同时进行词性标注
# ----> 6 seg = pkuseg.pkuseg(model_name='medicine',postag=True)
#
# NameError: name 'pkuseg' is not defined

# %%
import jieba 
list = jieba.cut('发病原因为右髋部摔伤后疼痛肿胀')
print("Default Mode: " + "/ ".join(list))  # 精确模式
# Out:
# Default Mode: 发病/ 原因/ 为/ 右/ 髋部/ 摔伤/ 后/ 疼痛/ 肿胀

# %%
#pkuseg包使用示例
seg.cut('发病原因为右髋部摔伤后疼痛肿胀')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a8893dab4a87> in <module>
#       1 #pkuseg包使用示例
# ----> 2 seg.cut('发病原因为右髋部摔伤后疼痛肿胀')
#
# NameError: name 'seg' is not defined

# %% [markdown]
# 可以看出，pkuseg包对医疗方面的文本有较好的分词效果。seg.cut(文本)的输出格式为[(第一个词，第一个词的词性),(第二个词，第二个词的词性),...,(第n个词，第n个词的词性)]。稍后在构建每个字的特征时我们会用到pkuseg的分词功能。

# %%
#加载医学的专业词汇词库THUOCL_medical.txt。这一文件是从https://github.com/thunlp/THUOCL中下载而来。
#文件中每行的格式为：医学名词 词频

#读取文件
with open('THUOCL_medical.txt') as f:
    medical_words = f.read().strip()
#获取医疗词汇表
medical_words_list = [words.strip().split('\t')[0] for words in medical_words.split('\n')]

# %%
#医疗词汇表示例，这一词汇表在我们构建特征时会用到。
medical_words_list[:10]
# Out:
# ['精神', '医院', '检查', '死亡', '恢复', '意识', '医疗', '治疗', '卫生', '患者']

# %% [markdown]
# 进行完上述准备工作后，我们接下来正式来构造特征。

# %%
def word2feature(sentence,i):
    '''
        返回句子sentence中第i个汉字的一些简单的特征
        入参：
            sentence：待处理的句子
            i：会返回第i个汉字的一些简单的特征
        出参：
            simple_feature：由一些简单的特征所组成的字典，字典的键为特征名，值为特征值
    '''
    simple_feature = {}
    simple_feature['word'] = sentence[i]   #当前字
    simple_feature['pre_word'] = sentence[i-1] if i>0 else 'start'    #前一个字
    simple_feature['after_word'] = sentence[i+1] if i<len(sentence)-1 else 'end'     #后一个字
    #接下来加入当前字的Bi-gram特征，即前一个字+当前字、当前字+后一个字
    simple_feature['pre_word_word'] = simple_feature['pre_word']+simple_feature['word']
    simple_feature['word_after_word'] = simple_feature['word']+simple_feature['after_word']
    #加入一个偏置项
    simple_feature['bias'] = 1
    return simple_feature

# %%
def sentence2feature(sentence):
    '''
        在word2feature定义的简单特征的基础上，增加一些复杂的特征，并返回句子中每个字对应的特征字典所组成的列表
        入参：
            sentence:待处理的句子
        出参：
            sentence_feature_list:句子中每个字对应的特征字典所组成的列表。格式为：[第一个字的特征字典，第二个字的特征字典，...，第n个字的特征字典]
    '''
    sentence_feature_list = [word2feature(sentence,i) for i in range(len(sentence))]
    #为每个字增加一些复杂的特征
    #增加当前字在分词后所在的词，该词的词性，该词的上一个词，该词的下一个词，该词是否为医疗专业词汇，该字是否为该词的第一个字
    word_index = 0    #指向字的指针，会逐步往后移动，其作用在之后可以看到
    #使用pkuseg对句子进行分词
    sentence_cut = seg.cut(sentence)
    #这里为和字进行区分，使用大写的WORD来表示词，小写的word来表示字
    for i,(WORD,nominal) in enumerate(sentence_cut):
        for j in range(word_index,word_index+len(WORD)):
            sentence_feature_list[j]['WORD'] = WORD     #当前字在分词后所在的词
            sentence_feature_list[j]['nominal'] = nominal     #该词的词性
            sentence_feature_list[j]['pre_WORD'] = sentence_cut[i-1][0] if i>0 else 'START'    #该词的上一个词
            sentence_feature_list[j]['after_WORD'] = sentence_cut[i+1][0] if i<len(sentence_cut)-1 else 'END'    #该词的下一个词
            sentence_feature_list[j]['is_medicalwords'] = 1 if WORD in medical_words_list else 0    #该词是否为医学专业词汇
        sentence_feature_list[word_index]['is_first'] = 1   #该字是否为该词的第一个字
        for j in range(word_index+1,word_index+len(WORD)):
            sentence_feature_list[j]['is_first'] = 0     #该字是否为该词的第一个字
        word_index = word_index+len(WORD)    #更新word_index的值
    return sentence_feature_list

# %%
#获取sentence_list中每句话中每个字对应的特征，并将其保存在feature_list中
#使用tqdm函数来输出一个进度条，以监控代码的运行过程
feature_list = [sentence2feature(sentence) for sentence in tqdm(sentence_list)]
# Out:
# 100%|██████████| 1198/1198 [01:08<00:00, 17.48it/s]

# %% [markdown]
# # CRF模型搭建

# %%
#首先对数据划分训练集和测试集
x_train,x_test,y_train,y_test = train_test_split(feature_list, label_list, test_size=0.3, random_state=2020)

# %%
#搭建一个CRF模型
crf = CRF(
    algorithm='lbfgs',   #训练算法
    c1=0.1,    #L1正则化系数
    c2=0.1,    #L2正则化系数
    max_iterations=100,     #优化算法的最大迭代次数
    all_possible_transitions=False
)
#使用crf模型对训练集进行训练
crf.fit(x_train,y_train)
# Out:
# /home/envy/anaconda3/envs/NULL/lib/python3.6/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_transitions=False, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
def predict(sentence):
    '''
        输出CRF预测的一个句子的BIO标注
        入参：
            sentence：待处理的句子
        出参：
            sent_bio：一个字典，字典的键为句子中的汉字，值为其对应的BIO标注
    '''
    #获取输入句子的特征
    fea = sentence2feature(sentence)
    #获取crf的预测值，格式为每个字的BIO标注列表
    pred = crf.predict_single(fea)
    #将句子中的汉字与其对应的BIO标注进行配对并以字典结构存储
    sent_bio = dict(zip(sentence,pred))
    return sent_bio

# %%
#使用predict函数对一个句子进行预测
predict('这是由于耳膜损伤导致的')
# Out:
# {'这': 'O',
#  '是': 'O',
#  '由': 'O',
#  '于': 'O',
#  '耳': 'B-BODY',
#  '膜': 'I-BODY',
#  '损': 'O',
#  '伤': 'O',
#  '导': 'O',
#  '致': 'O',
#  '的': 'O'}

# %% [markdown]
# 可以看出CRF模型能够有效的识别出这句话中的实体，接下来我们用CRF模型对我们的测试集进行预测。

# %%
#获取测试集的预测值
y_pred = crf.predict(x_test)

# %% [markdown]
# # 模型评估

# %% [markdown]
# 使用sklearn_crfsuite中自带的metrics包可对模型进行有效的评估

# %%
#获取crf模型的全部标签
labels = list(crf.classes_)
#由于标签O过多，而我们对其他标签更感兴趣。为了解决这个问题，我们标签O移除。
labels.remove('O')
#查看除'O'外的全部标签
labels
# Out:
# ['B-BODY',
#  'I-BODY',
#  'B-TREATMENT',
#  'I-TREATMENT',
#  'B-EXAMINATIONS',
#  'I-EXAMINATIONS',
#  'B-SIGNS',
#  'I-SIGNS',
#  'B-DISEASES',
#  'I-DISEASES']

# %%
#计算除O之外的所有标签计算的平均F1分数。
metrics.flat_f1_score(y_test, y_pred,
                      average='micro', labels=labels)
# Out:
# 0.9416829296292045

# %%
#查看每个类别的预测情况
print(metrics.flat_classification_report(
    y_test, y_pred, labels=labels, digits=3
))
# Out:
# /home/envy/anaconda3/envs/NULL/lib/python3.6/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-BODY', 'I-BODY', 'B-TREATMENT', 'I-TREATMENT', 'B-EXAMINATIONS', 'I-EXAMINATIONS', 'B-SIGNS', 'I-SIGNS', 'B-DISEASES', 'I-DISEASES'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
#                 precision    recall  f1-score   support
#
#         B-BODY      0.936     0.919     0.928      3299
#         I-BODY      0.921     0.936     0.928      5870
#    B-TREATMENT      0.889     0.803     0.844       300
#    I-TREATMENT      0.925     0.830     0.875      1389
# B-EXAMINATIONS      0.972     0.971     0.971      2886
# I-EXAMINATIONS      0.961     0.974     0.967      6495
#        B-SIGNS      0.976     0.980     0.978      2408
#        I-SIGNS      0.977     0.977     0.977      2664
#     B-DISEASES      0.849     0.678     0.754       199
#     I-DISEASES      0.830     0.610     0.703       767
#
#      micro avg      0.947     0.937     0.942     26277
#      macro avg      0.924     0.868     0.893     26277
#   weighted avg      0.946     0.937     0.940     26277

# %% [markdown]
# # BiLSTM-CRF

# %% [markdown]
# CRF模型还可与BiLSTM模型结合来解决实体识别问题，这样的好处是BiLSTM可以自动获取文本的特征，我们便不需要自己去定义特征，不需要再进行文本特征工程部分。

# %% [markdown]
# 由于BiLSTM-CRF的代码过于冗长，且实现这一代码并不是我们的重点，而仅做展示之用。所以我们把BiLSTM-CRF模型的实现细节均在BiLSTM_CRF.py中实现。这里仅展示部分关键部分。

# %%
from BiLSTM_CRF import *

# %%
#将word映射到id
word2id = word_to_id(sentence_list)
#将label映射到id
tag2id = tag_to_id(label_list)

# %%
#查看label与id的映射关系
tag2id
# Out:
# {'O': 0,
#  'B-TREATMENT': 1,
#  'I-TREATMENT': 2,
#  'B-BODY': 3,
#  'I-BODY': 4,
#  'B-SIGNS': 5,
#  'I-SIGNS': 6,
#  'B-EXAMINATIONS': 7,
#  'I-EXAMINATIONS': 8,
#  'B-DISEASES': 9,
#  'I-DISEASES': 10,
#  '<unk>': 11,
#  '<pad>': 12,
#  '<start>': 13,
#  '<end>': 14}

# %% [markdown]
# LSTM模型训练的时候需要在word2id和tag2id加入PAD和UNK，如果是加了CRF的lstm还要加入<start>和<end> (解码的时候需要用到)。word2id的格式与tag2id的格式类似。

# %%
#按照与CRF模型划分训练集测试集时相同的比例和相同的随机数种子对sentence_list与label_list划分训练集合测试集
x_train_lstmcrf,x_test_lstmcrf,y_train_lstmcrf,y_test_lstmcrf = train_test_split(sentence_list, label_list, test_size=0.3, random_state=2020)

# %%
#为每句话后加入一个"<end>" token
x_train_lstmcrf,y_train_lstmcrf = prepocess_data_for_lstmcrf(x_train_lstmcrf,y_train_lstmcrf)
x_test_lstmcrf,y_test_lstmcrf = prepocess_data_for_lstmcrf(x_test_lstmcrf,y_test_lstmcrf,test=True)

# %%
#搭建一个BiLSTM_CRF模型
model = BiLSTM_CRF_Model(vocab_size=len(word2id),out_size=len(tag2id),batch_size=64, epochs=30)
#在训练集上进行训练
model.train(x_train_lstmcrf,y_train_lstmcrf,word2id,tag2id)
# Out:
# Epoch 1, step/total_step: 10/14 71.43% Loss:704.2072
# Epoch 1, Val Loss:304.0656
# Epoch 2, step/total_step: 10/14 71.43% Loss:379.6861
# Epoch 2, Val Loss:235.2745
# Epoch 3, step/total_step: 10/14 71.43% Loss:310.2055
# Epoch 3, Val Loss:210.7312
# Epoch 4, step/total_step: 10/14 71.43% Loss:277.9240
# Epoch 4, Val Loss:178.1358
# Epoch 5, step/total_step: 10/14 71.43% Loss:232.9529
# Epoch 5, Val Loss:149.0497
# Epoch 6, step/total_step: 10/14 71.43% Loss:194.8497
# Epoch 6, Val Loss:123.6975
# Epoch 7, step/total_step: 10/14 71.43% Loss:161.6577
# Epoch 7, Val Loss:105.9033
# Epoch 8, step/total_step: 10/14 71.43% Loss:136.8538
# Epoch 8, Val Loss:89.5023
# Epoch 9, step/total_step: 10/14 71.43% Loss:115.7047
# Epoch 9, Val Loss:74.7383
# Epoch 10, step/total_step: 10/14 71.43% Loss:97.6705
# Epoch 10, Val Loss:65.9354
# Epoch 11, step/total_step: 10/14 71.43% Loss:85.6503
# Epoch 11, Val Loss:58.4867
# Epoch 12, step/total_step: 10/14 71.43% Loss:75.9036
# Epoch 12, Val Loss:53.6536
# Epoch 13, step/total_step: 10/14 71.43% Loss:69.1036
# Epoch 13, Val Loss:49.2343
# Epoch 14, step/total_step: 10/14 71.43% Loss:63.1410
# Epoch 14, Val Loss:44.5149
# Epoch 15, step/total_step: 10/14 71.43% Loss:57.7635
# Epoch 15, Val Loss:39.3853
# Epoch 16, step/total_step: 10/14 71.43% Loss:51.8154
# Epoch 16, Val Loss:36.2656
# Epoch 17, step/total_step: 10/14 71.43% Loss:47.9855
# Epoch 17, Val Loss:33.5586
# Epoch 18, step/total_step: 10/14 71.43% Loss:44.1749
# Epoch 18, Val Loss:31.3266
# Epoch 19, step/total_step: 10/14 71.43% Loss:41.5092
# Epoch 19, Val Loss:29.2712
# Epoch 20, step/total_step: 10/14 71.43% Loss:38.6559
# Epoch 20, Val Loss:28.1205
# Epoch 21, step/total_step: 10/14 71.43% Loss:37.1045
# Epoch 21, Val Loss:26.1546
# Epoch 22, step/total_step: 10/14 71.43% Loss:34.4247
# Epoch 22, Val Loss:25.3019
# Epoch 23, step/total_step: 10/14 71.43% Loss:33.5837
# Epoch 23, Val Loss:24.5510
# Epoch 24, step/total_step: 10/14 71.43% Loss:31.7224
# Epoch 24, Val Loss:23.5408
# Epoch 25, step/total_step: 10/14 71.43% Loss:30.6489
# Epoch 25, Val Loss:22.0607
# Epoch 26, step/total_step: 10/14 71.43% Loss:28.9199
# Epoch 26, Val Loss:21.9007
# Epoch 27, step/total_step: 10/14 71.43% Loss:28.5776
# Epoch 27, Val Loss:20.7348
# Epoch 28, step/total_step: 10/14 71.43% Loss:27.0589
# Epoch 28, Val Loss:20.6038
# Epoch 29, step/total_step: 10/14 71.43% Loss:26.9689
# Epoch 29, Val Loss:19.3230
# Epoch 30, step/total_step: 10/14 71.43% Loss:24.9454
# Epoch 30, Val Loss:19.2313

# %%
#获取测试集的预测值
y_pred_lstmcrf, _ = model.test(x_test_lstmcrf,y_test_lstmcrf,word2id,tag2id)
# Out:
# /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:1236: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters().

# %%
#计算BiLSTM-CRF模型除O之外的所有标签计算的平均F1分数。
metrics.flat_f1_score(y_test_lstmcrf, y_pred_lstmcrf,
                      average='micro', labels=labels)
# Out:
# 0.9281288723667905

# %%
#查看BiLSTM-CRF模型每个类别的预测情况
print(metrics.flat_classification_report(
    y_test_lstmcrf, y_pred_lstmcrf, labels=labels, digits=3
))
# Out:
# /home/envy/anaconda3/envs/NULL/lib/python3.6/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-BODY', 'I-BODY', 'B-TREATMENT', 'I-TREATMENT', 'B-EXAMINATIONS', 'I-EXAMINATIONS', 'B-SIGNS', 'I-SIGNS', 'B-DISEASES', 'I-DISEASES'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)
#                 precision    recall  f1-score   support
#
#         B-BODY      0.953     0.849     0.898      3299
#         I-BODY      0.912     0.918     0.915      5870
#    B-TREATMENT      0.888     0.607     0.721       300
#    I-TREATMENT      0.886     0.870     0.878      1389
# B-EXAMINATIONS      0.961     0.950     0.956      2886
# I-EXAMINATIONS      0.952     0.962     0.957      6495
#        B-SIGNS      0.979     0.951     0.965      2408
#        I-SIGNS      0.975     0.959     0.967      2664
#     B-DISEASES      0.975     0.598     0.741       199
#     I-DISEASES      0.950     0.568     0.711       767
#
#      micro avg      0.945     0.912     0.928     26277
#      macro avg      0.943     0.823     0.871     26277
#   weighted avg      0.945     0.912     0.926     26277

# %%
import numpy as np
6.539* np.array([5560, 20100, 18800, 8050, 23500, 28600, 20700, 16000, 0])
# Out:
# array([ 36356.84, 131433.9 , 122933.2 ,  52638.95, 153666.5 , 187015.4 ,
#        135357.3 , 104624.  ,      0.  ])
